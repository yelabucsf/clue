# %% [markdown]
# # Bulk Analysis
# Here is the analysis of the bulk RNA-sequencing data we performed on PBMCs from 3 individuals, profiling their expression under stimulation of 5 molecules (IFN-gamma, IFN-beta, PMA/Ionomycin, R848, and TNF-alpha) at 5 time points (0, 3, 6, 9, and 12) hours.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Load in packages

# %% [markdown]
# Some standard ones here:

# %%
import pandas as pd
from tqdm.notebook import tqdm
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import rcParams
import matplotlib as mpl
import seaborn as sns
import pickle as pkl
import itertools as it
from functools import reduce
import scanpy as sc
import scipy

# %% [markdown]
# And then some from the [goatools](https://github.com/tanghaibao/goatools) Gene Ontology package for Python. Most of the code here modeled after the [notebooks](https://github.com/tanghaibao/goatools#ipython-notebooks) found on the Github.

# %%
from goatools.base import download_go_basic_obo
from goatools.base import download_ncbi_associations
from goatools.obo_parser import GODag
from goatools.anno.genetogo_reader import Gene2GoReader
from goatools.test_data.genes_NCBI_9606_ProteinCoding import GENEID2NT as GeneID2nt_hum
from goatools.goea.go_enrichment_ns import GOEnrichmentStudyNS

# %% [markdown]
# Some nice parameters I like, stolen from Scanpy:

# %%
fontsize = 14

# %%
rcParams['figure.figsize'] = (4, 4)
rcParams['figure.dpi'] = 80
rcParams['figure.subplot.left'] = 0.18
rcParams['figure.subplot.right'] = 0.96
rcParams['figure.subplot.bottom'] = 0.15
rcParams['figure.subplot.top'] = 0.91

rcParams['lines.linewidth'] = 1.5  # the line width of the frame
rcParams['lines.markersize'] = 6
rcParams['lines.markeredgewidth'] = 1

# font
rcParams['font.sans-serif'] = [
'Arial',
'Helvetica',
'DejaVu Sans',
'Bitstream Vera Sans',
'sans-serif',
]
fontsize = fontsize
rcParams['font.size'] = fontsize
rcParams['legend.fontsize'] = 0.92 * fontsize
rcParams['axes.titlesize'] = fontsize
rcParams['axes.labelsize'] = fontsize

# legend
rcParams['legend.numpoints'] = 1
rcParams['legend.scatterpoints'] = 1
rcParams['legend.handlelength'] = 0.5
rcParams['legend.handletextpad'] = 0.4

# lines
rcParams['axes.linewidth'] = 0.8
rcParams['axes.edgecolor'] = 'black'
rcParams['axes.facecolor'] = 'white'

# ticks
rcParams['xtick.color'] = 'k'
rcParams['ytick.color'] = 'k'
rcParams['xtick.labelsize'] = fontsize
rcParams['ytick.labelsize'] = fontsize

# axes grid
rcParams['axes.grid'] = True
rcParams['grid.color'] = '.8'

# %% [markdown]
# Define a path prefix:

# %%
prefix = '/data/codec/bulk.jan20/' # path to the dir holding all relevant files

# %% [markdown]
# ### Read in files

# %% [markdown]
# I have a separate notebook that creates a dictinoary to map ENSG IDs to gene names. I load that in here:

# %%
with open(prefix + "ensgdict.pkl", 'rb') as file:
    ensgdict = pkl.load(file)

# %% [markdown]
# Quick check on the dictionary to see that it looks good.

# %%
print(list(ensgdict.keys())[:5])
print(list(ensgdict.values())[:5])
# Out:
# ['ENSG00000243485', 'ENSG00000237613', 'ENSG00000186092', 'ENSG00000238009', 'ENSG00000239945']
# ['MIR1302-2HG', 'FAM138A', 'OR4F5', 'AL627309.1', 'AL627309.3']

# %% [markdown]
# Run some bash commands to read all the file names in the `read.counts` directory, holding the counts from `htseq-count`.

# %%
fns = !ls -1 {prefix}"read.counts/"

# %% [markdown]
# Extract out sample names:

# %%
samples = list()
for fn in fns:
    samples.append(fn.split('_')[0].split('-')) # this parses the file names, I named them in a systematic way
samples = np.unique(np.array(samples).flatten())

# %%
samples
# Out:
# array(['0HR', '12HR', '1895', '2061', '3HR', '6HR', '731', '9HR',
#        'Control', 'IFNB', 'IFNG', 'None', 'PMAI', 'R848', 'TNFa'],
#       dtype='<U7')

# %% [markdown]
# Create a `pd.MultiIndex`, very useful in these cases of multiple variables defining each individual row. I only do the non-zero time point here because the 0 hour time point had only 3 samples. Generating with `.from_product` would make superfluous indices.

# %%
multidx = pd.MultiIndex.from_product([['731', '1895', '2061'],['3HR','6HR','9HR','12HR'],['Control', 'IFNB', 'IFNG', 'PMAI', 'R848', 'TNFa']])

# %% [markdown]
# Now add in those 3 time zero time points.

# %%
multidx = multidx.insert(0, ('731', '0HR', 'None'))
multidx = multidx.insert(25, ('1895', '0HR', 'None'))
multidx = multidx.insert(50, ('2061', '0HR', 'None'))

# %% [markdown]
# Read in the read counts into a list of dataframes.

# %%
dfs = list()
for fn in tqdm(fns):
    df = pd.read_csv(prefix + "read.counts/" + fn, sep='\t', header=None).set_index(0).T
    df.index.name = 'sample'
    df.index = [tuple(fn.split('_')[0].split('-'))]
    dfs.append(df)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=75.0), HTML(value='')))

# %%
dfs[0]
# Out:
# 0                  ENSG00000000003  ENSG00000000005  ENSG00000000419  \
# (1895, 0HR, None)               12                0              106
#
# 0                  ENSG00000000457  ENSG00000000460  ENSG00000000938  \
# (1895, 0HR, None)               54                0             1879
#
# 0                  ENSG00000000971  ENSG00000001036  ENSG00000001084  \
# (1895, 0HR, None)                4              117              105
#
# 0                  ENSG00000001167  ...  ENSG00000285492  ENSG00000285505  \
# (1895, 0HR, None)               86  ...               10                0
#
# 0                  ENSG00000285508  ENSG00000285509  ENSG00000285513  \
# (1895, 0HR, None)                0                0                0
#
# 0                  __no_feature  __ambiguous  __too_low_aQual  __not_aligned  \
# (1895, 0HR, None)       3813417       104400                0              0
#
# 0                  __alignment_not_unique
# (1895, 0HR, None)                 4017668
#
# [1 rows x 33543 columns]

# %% [markdown]
# After trying multiple times, I can't figure out which values (or sum thereof) in the `htseq-count` output corresponds to total library size. So I just got total reads from the original fastqs and put all the total read counts in a single file. Reading it in here:

# %%
with open(prefix + 'totreadscounts.txt','r') as file:
    lines = file.readlines()
    libreads = dict([(tuple(j[0].split("-")), int(j[1])) for j in [i.strip().split(",") for i in lines]])

# I want the timepoint as an integer
# I couldn't figure out how to adjust this inplace, so just building a new one

_libreads = dict()
for i in libreads:
    _libreads[tuple([i[0],i[1].strip('HR'),i[2]])] = libreads[i]
libreads = _libreads

# %% [markdown]
# ### Build the Big Counts Matrix
#
# Building a `pd.DataFrame` with the counts from all samples.

# %%
counts = dict()

# %%
counts['raw'] = pd.concat(dfs)

# %% [markdown]
# Make the index a `pd.Multiindex`.

# %%
counts['raw'].index = pd.MultiIndex.from_tuples([(i[0],i[1].strip('HR'), i[2]) for i in counts['raw'].index.values])

# %%
counts['raw'].index.names = ['IND','TIME','STIM']

# %% [markdown]
# Now would be a good time to define some useful variables:

# %%
stims = ['IFNG','IFNB','PMAI','R848','TNFa'] # I wish I made TNFa TNFA for consistency
hours = ['3','6','9','12']
tests = ['TC'] + hours
inds=['1895','2061','731']

# %% [markdown]
# Remap all the ENSG ids to their actual gene name.

# %%
newcols = counts['raw'].columns.map(ensgdict).tolist()
newcols[-5:] = counts['raw'].columns[-5:]

# %%
counts['raw'].columns = newcols

# %%
counts['raw']
# Out:
#                    TSPAN6  TNMD  DPM1  SCYL3  C1orf112   FGR  CFH  FUCA2  \
# IND  TIME STIM
# 1895 0    None         12     0   106     54         0  1879    4    117
#      12   Control       4     0   167    122         2   230    0     64
#           IFNB          2     0   179     92         7   174    5     76
#           IFNG          7     0   187    193         9   647   12     71
#           PMAI         13     0   547     58         4   248    0     22
# ...                   ...   ...   ...    ...       ...   ...  ...    ...
# 731  9    IFNB          3     0    92     63        11   125    0     15
#           IFNG          4     0   238    200         7   574    8     26
#           PMAI          0     0   334     43         0   839    9      6
#           R848          2     0   259    226        19   198    6     12
#           TNFa          6     0   252    184        20   508    3     59
#
#                    GCLC  NFYA  ...  AL356417.3  AC010616.2  AL034430.1  \
# IND  TIME STIM                 ...
# 1895 0    None      105    86  ...          10           0           0
#      12   Control   477    86  ...           0           0           0
#           IFNB      316   111  ...           0           0           0
#           IFNG      836    69  ...           0           0           0
#           PMAI      215   138  ...           0           0           0
# ...                 ...   ...  ...         ...         ...         ...
# 731  9    IFNB      204    63  ...           0           0           0
#           IFNG      672    68  ...           0           0           0
#           PMAI      247   134  ...           4           0           0
#           R848      211    62  ...           1           0           0
#           TNFa      347    52  ...           0           0           0
#
#                    AP000646.1  AP006216.3  __no_feature  __ambiguous  \
# IND  TIME STIM
# 1895 0    None              0           0       3813417       104400
#      12   Control           0           0       2218082        87556
#           IFNB              0           0       1893717        85918
#           IFNG              0           0       2955527       137238
#           PMAI              0           0       2329449       101390
# ...                       ...         ...           ...          ...
# 731  9    IFNB              0           0       1657083        65585
#           IFNG              0           0       2748356       103415
#           PMAI              0           0       2802613        91004
#           R848              0           0       3864753       131514
#           TNFa              0           0       3401409       113479
#
#                    __too_low_aQual  __not_aligned  __alignment_not_unique
# IND  TIME STIM
# 1895 0    None                   0              0                 4017668
#      12   Control                0              0                 2633375
#           IFNB                   0              0                 2366138
#           IFNG                   0              0                 3947510
#           PMAI                   0              0                 3612969
# ...                            ...            ...                     ...
# 731  9    IFNB                   0              0                 2190246
#           IFNG                   0              0                 3985939
#           PMAI                   0              0                 4059545
#           R848                   0              0                 5261412
#           TNFa                   0              0                 5125559
#
# [75 rows x 33543 columns]

# %% [markdown]
# At this point, I'm going to export to a pickle to load into a separate notebook to prepare the raw counts `df` for DESeq2. I run DESeq2 in yet another notebook, and then load the files in here further down in this notebook.

# %%
# with open(prefix + "counts.pkl", "wb") as file:
#     pkl.dump(counts, file)

# %%
with open(prefix + "counts.pkl", "rb") as file:
    counts = pd.read_pickle(file)

# %% [markdown]
# Now that just the raw read counts files are exported, I'd like to separate out some of the meta data from the `htseq-count` output.

# %%
counts['meta'] = counts['raw'].iloc[:,-5:] # only the last 5 columns contain metadata
counts['raw'] = counts['raw'].iloc[:,:-5]

counts['meta'].columns = [i.strip("__") for i in counts['meta'].columns] # get rid of the double underscore at the beginning, it has no use as far as I can see

# %% [markdown]
# I would like to add my `libreads` data to `counts[meta]`.

# %%
s = pd.Series(libreads)
s.index.names = ['IND','TIME','STIM'] # need to give the index names so they match up to the right ones in counts[meta]
counts['meta']['tot_reads'] = s

# %%
counts['meta']
# Out:
#                    no_feature  ambiguous  too_low_aQual  not_aligned  \
# IND  TIME STIM
# 1895 0    None        3813417     104400              0            0
#      12   Control     2218082      87556              0            0
#           IFNB        1893717      85918              0            0
#           IFNG        2955527     137238              0            0
#           PMAI        2329449     101390              0            0
# ...                       ...        ...            ...          ...
# 731  9    IFNB        1657083      65585              0            0
#           IFNG        2748356     103415              0            0
#           PMAI        2802613      91004              0            0
#           R848        3864753     131514              0            0
#           TNFa        3401409     113479              0            0
#
#                    alignment_not_unique  tot_reads
# IND  TIME STIM
# 1895 0    None                  4017668   15056748
#      12   Control               2633375    9990474
#           IFNB                  2366138    8809236
#           IFNG                  3947510   14037893
#           PMAI                  3612969   12776156
# ...                                 ...        ...
# 731  9    IFNB                  2190246    7751220
#           IFNG                  3985939   12765986
#           PMAI                  4059545   13111938
#           R848                  5261412   17304522
#           TNFa                  5125559   15290556
#
# [75 rows x 6 columns]

# %% [markdown]
# ### Plotting of Meta Data

# %%
fig, ax = plt.subplots(2,2,figsize=(12,12)) # make a figure with 4 sub plots
colormap = plt.cm.Spectral # use this greate colormap that can better differentiate our many samples
cs = [colormap(i) for i in np.linspace(0, 1, counts['raw'].shape[0])] # get colors mapped linearly from the colormap 

# zip the columns of the data (and theyre label in the plot) with the axes from the subplots
for data, ax in zip([('no_feature', 'unaligned'), 
                     ('ambiguous', 'ambiguous'),
                     ('alignment_not_unique', 'duplicated'),
                     ('tot_reads', 'in library')
                    ], np.ravel(ax)):
    
    ax.scatter(counts['raw'].sum(axis=1).values,
               counts['meta'][data[0]],c=cs);
    
    ax.set_xlabel('Total reads aligned')
    ax.set_ylabel('Total reads %s' % data[1]);
    ax.ticklabel_format(axis="x", style="sci", scilimits=(0,0))
    ax.ticklabel_format(axis="y", style="sci", scilimits=(0,0))
plt.tight_layout()

# %% [markdown]
# ### Make a Normalized Counts Matrix

# %% [markdown]
# DESeq2 is *likely* normalizing by the sum of the read counts from just the genes. Although I've showed all of these things correlate with each other above, I think its more proper to normalize by the total reads in the library. Unfortunately I don't think it's worth trying to figure out how to input total reads in DESeq2 to normalize by, but I still think the results from DESeq2 are still valid. However, for my own purposes in this notebook below (mostly just calculating mean expression across genes) I will normalize by total reads in library (from the raw fastqs).

# %%
counts['raw'] = counts['raw'].astype(np.float128) # retype the raw counts as a high-precision float

# %%
counts['norm'] = counts['raw'].div(counts['meta']['tot_reads'].values, axis=0) # divide by the total reads

# %% [markdown]
# Now they're *technically* normalized, but the expression values for any individual gene are extremely small percentages. To bring them back into the "integer" realm of real numbers, I will take the smallest non-zero value in the entire matrix and divide all values by this. Now, zero counts are still zero, the smallest non-zero count is 1, and everything that had proportionally more counts than that is some real number above 1.

# %%
nonzero_min = counts['norm'].values.flatten()[(counts['norm'].values > 0).flatten()].min()
counts['norm'] = counts['norm'].div(nonzero_min) # could take a bit

# %% [markdown]
# Also going to make a log fold change matrix as well, for use later:

# %%
for cond in ['TNFa','IFNB','IFNG','R848','PMAI']:
    print(cond)
#     counts['norm']
# Out:
# TNFa
# IFNB
# IFNG
# R848
# PMAI

# %%
norm_lfc = list()
for ind, hour in it.product(inds, hours):
    df = counts['norm'].xs([hour,ind], level=['TIME','IND']) + 1 # +1 to avoid NaNs
    for stim in stims:
        row = [ind, hour, stim] + np.log2(np.divide((df).loc[stim], (df).loc['Control'])).values.tolist()
        norm_lfc.append(row)

# %%
counts['norm_lfc'] = pd.DataFrame(data=norm_lfc,columns=['IND','TIME','STIM'] + counts['norm'].columns.tolist())

# %%
norm_lfc = list()
for ind, hour in it.product(inds, hours):
    df = counts['raw'].xs([hour,ind], level=['TIME','IND']) + 1 # +1 to avoid NaNs
    for stim in stims:
        row = [ind, hour, stim] + np.log2(np.divide((df).loc[stim], (df).loc['Control'])).values.tolist()
        norm_lfc.append(row)

# %%
counts['raw_lfc'] = pd.DataFrame(data=norm_lfc,columns=['IND','TIME','STIM'] + counts['raw'].columns.tolist())

# %%
counts['norm_lfc'].index = pd.MultiIndex.from_frame(counts['norm_lfc'][['IND','TIME','STIM']])
counts['norm_lfc'].drop(columns=['IND','TIME','STIM'], inplace=True)

# %%
counts['raw_lfc'].index = pd.MultiIndex.from_frame(counts['raw_lfc'][['IND','TIME','STIM']])
counts['raw_lfc'].drop(columns=['IND','TIME','STIM'], inplace=True)

# %% [markdown]
# ### Load in DESeq2 Results

# %% [markdown]
# As mentioned, I ran DESeq2 in a separate notebook. I ran two tests, one that just compares every stim to the control for every non-zero time point (labeled by the hour in the cell below), and another that tries to model stimulation-specific changes over time (labeled as TC below). I'll read in all, but since I'm not *exactly* sure how to interpret the latter, I'm really only going to focus on the former in this notebook.

# %% [markdown]
# Read in the results.

# %%
de = dict() # differential expression dictionary
for stim in stims:
    de[stim] = dict()
    
combos = it.product(stims, tests)
for combo in combos:
    de[combo[0]][combo[1]] = pd.read_csv(prefix + 'deseq2.res/' + combo[0] + '.' + combo[1] + '.csv', index_col=0).dropna()

# %% [markdown]
# ## DE Genes: Upregulated

# %% [markdown]
# Just focusing on those genes that were increased in expression relatively to control. Using the 90th percentile positive log2fc and the p_adj < 0.05, I will extract out differentially expressed genes.

# %%
#########################################################################################################
# Through testing with multiple samples, I think a good metric for determining differentially expressed genes involves a strict p_adj value cutoff (0.05) 
# and a dynamic log fold change threshold that changes depending on the sample. I'm using the log2foldchange value at the 90th %ile of positive values
#########################################################################################################

de_genes = dict() # make a dictionary

for stim in stims:
    de_genes[stim] = dict() # each value will be each stim, itself be a dictionary with values of hours

# for each stim, each non-zero hour...
combos = list(it.product(stims, hours)) 
for combo in combos: 
    stim = combo[0]
    hour = combo[1]
    df = de[stim][hour] # get the DE results
    df = df[df['log2FoldChange'] > 0] # only keep those that are positive
    fc_thresh = np.percentile(df['log2FoldChange'],90) # calculate threshold of now only positive values
    
    # extract out genes, add them to the dictionary as a list
    de_genes[stim][hour] = df.index[(df['log2FoldChange'] > fc_thresh) & 
                                    (df['padj'] < 0.05)
                                   ].tolist()

# %% [markdown]
# ### Plot The Positive Half of the Volcano Plot for Any Sample

# %%
stim = 'R848'
hour = '12'

# %%
df = de[stim][hour]
df = df[df['log2FoldChange'] > 0]
fc_thresh = np.percentile(df['log2FoldChange'],90)

plt.scatter(df['log2FoldChange'].values, 
            -np.log10(df['padj']).values,
           s=1);

xlim = plt.gca().get_xlim()
ylim = plt.gca().get_ylim()

# drawing cutoffs here
plt.plot(xlim, [-np.log10(0.05)]*2, linewidth=1, c='r', linestyle='--');
plt.plot([fc_thresh]*2, ylim, linewidth=1, c='r', linestyle='--');

plt.xlabel('log2FoldChange (only > 0)')
plt.ylabel('-log10(p_adj)');

# %% [markdown]
# Get the number of genes that were differentially expressed in each sample.

# %%
num_genes = pd.DataFrame(index=stims, columns=hours)
for i in de_genes:
    for j in de_genes[i]:
        num_genes.loc[i, j] = len(de_genes[i][j])

# %%
num_genes
# Out:
#         3    6    9   12
# IFNG  270  308  267  343
# IFNB  388  429  305  358
# PMAI  428  426  455  457
# R848  409  417  379  430
# TNFa  128  179  155  119

# %% [markdown]
# ### Build the Jaccard Index of Gene Sets
#
# The Jaccard index is the length of the intersection over the union of two sets of items. Shows us how similar the gene sets are.

# %%
# build an "overlap" DataFrame
overlap = pd.DataFrame(np.zeros((len(combos),len(combos))), index=combos, columns=combos)

# %%
# for each combination of combinations (of stim-hours)...
for c_c in tqdm(it.product(combos,repeat=2)):
    c0 = c_c[0]
    c1 = c_c[1]
    
    g0 = de_genes[c0[0]][c0[1]] # get the de genes from stim-hour one
    g1 = de_genes[c1[0]][c1[1]] # get the de genes from stim-hour two
    
    # fill in the dataframe with the jaccard index
    overlap.loc[c0, c1] = len(np.intersect1d(g0, g1))/len(np.union1d(g0, g1))
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))

# %% [markdown]
# The Jaccard Index similarity matrix should be symmetrical. Therefore, the lower half of the triangle is redundant. For that reason, I'll build a mask to hide the lower triangle.

# %%
mask = ~np.triu(np.ones_like(overlap.values, dtype=np.bool), k=0)

# %%
plt.figure(figsize=(10,10))
ax = plt.gca()
ax.xaxis.tick_top()
ax.yaxis.tick_right()
sns.heatmap(overlap, mask=mask, ax=ax, cbar=None);
plt.xticks(rotation=45, ha='left');
plt.tight_layout()

# %% [markdown]
# ### LogFC Validation

# %% [markdown]
# I would like to quickly confirm that the log fold change I calculated here is recapitulated in the ones returned by DESeq2.

# %%
df = counts['norm_lfc'].loc[:,~counts['norm_lfc'].columns.duplicated()].copy()
# df = counts['raw_lfc'].loc[:,~counts['raw_lfc'].columns.duplicated()].copy()

# %%
fig, ax = plt.subplots(1, 4, figsize=(15,3))
for ax in ax:
    stim = np.random.choice(stims)
    hour = np.random.choice(hours)
    genes = de[stim][hour]['log2FoldChange'].index
    x = de[stim][hour]['log2FoldChange'].values
    y = df.loc[(df.index.get_level_values('STIM') == stim) & (df.index.get_level_values('TIME') == hour),genes].mean(0).values
    ax.scatter(x, y, s=1);

# %% [markdown]
# Okay, they correlate, but I'm not sure why they aren't exactly the same. Perhaps DESeq2 does some more complex corrections when calculating. I think I'll take the ones I have at face value though.

# %% [markdown]
# ## DE Genes: 2-sided, Static Cutoffs

# %% [markdown]
# Using a static cutoff for LFC and strict p_adj < 0.01, I will now extract out differentially expressed genes. At Hyun's suggestion, using only the top _n_ significant genes from each comparison, since some conditions like PMAI and R848 have 1000s, while TNF-alpha conditions have in the 10s or 100. Using the top 200 from each condition will not bias the heatmap towards the most stimulating conditions.

# %%
de_genes = dict() # make a dictionary

for stim in stims:
    de_genes[stim] = dict() # each value will be each stim, itself be a dictionary with values of hours

# for each stim, each non-zero hour...
combos = list(it.product(stims, hours))
num_top_genes_to_keep = 200
for combo in combos: 
    stim = combo[0]
    hour = combo[1]
    df = de[stim][hour] # get the DE results
    df = df[(df['log2FoldChange'] > 2) | (df['log2FoldChange'] < -2)]
    
    # extract out genes, add them to the dictionary as a list
    df_significant = df[(df['padj'] < 0.01)]
    de_genes[stim][hour] = df.sort_values('padj').index[:num_top_genes_to_keep]

# %%
all_de_genes = list()
for stim in stims:
    for hour in hours:
        de_genes_list = de_genes[stim][hour]
        print((stim, hour, len(de_genes_list)))
        all_de_genes.append(de_genes[stim][hour])
# Out:
# ('IFNG', '3', 200)
# ('IFNG', '6', 200)
# ('IFNG', '9', 200)
# ('IFNG', '12', 200)
# ('IFNB', '3', 200)
# ('IFNB', '6', 200)
# ('IFNB', '9', 200)
# ('IFNB', '12', 200)
# ('PMAI', '3', 200)
# ('PMAI', '6', 200)
# ('PMAI', '9', 200)
# ('PMAI', '12', 200)
# ('R848', '3', 200)
# ('R848', '6', 200)
# ('R848', '9', 200)
# ('R848', '12', 200)
# ('TNFa', '3', 14)
# ('TNFa', '6', 57)
# ('TNFa', '9', 58)
# ('TNFa', '12', 200)

# %%
all_de_genes = np.unique([i for j in all_de_genes for i in j])

# %% [markdown]
# Turn the counts matrix into an adata object for easy processing like normalize, log1p, and scaling.

# %%
counts_for_heatmap = counts['raw'].sort_values(by=['STIM', 'TIME']).copy() # this fucked me over, be careful
obs = pd.DataFrame(index=['-'.join(i) for i in counts_for_heatmap.index.values])
var = pd.DataFrame(index=counts['raw'].columns)

# %%
adata = sc.AnnData(X=counts_for_heatmap.values, obs=obs, var=var)
adata.var_names_make_unique()
# Out:
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 75 × 33538

# %%
sc.pp.normalize_total(adata, target_sum=1e6)

# %%
adata.raw = adata.copy()

# %%
sc.pp.log1p(adata)

# %%
sc.pp.scale(adata)

# %% [markdown]
# Now back to a df because it's simpler.

# %%
df_de = pd.DataFrame(adata[:,all_de_genes].X, index=obs.index, columns=all_de_genes)

# %%
df_de.shape
# Out:
# (75, 1229)

# %% [markdown]
# ## Plotting

# %% [markdown]
# I want to show in the following order, based on what I've observed over the course of my data analysis, this is in quasi-order of strength of signal.

# %%
ordering_dict = {'None':0,
                 'Control': 1,
                 'TNFa': 2,
                 'IFNG': 3,
                 'IFNB': 4,
                 'R848': 5,
                 'PMAI':6
                }

# %% [markdown]
# ### Heirarchical Clustering

# %% [markdown]
# When I originally created this notebook, I wanted to use heirarchical clustering to find gene modules by just cutting the tree at a certain point. While this yielded some biologically relevant modules, it required me to ask the `cut_tree()` function to find _many_ more clusters than were actually relevant or contained a sufficient number of genes, as shown below:

# %%
df_de_ordered = df_de.loc[['-'.join(i) for i in sorted(df_de.index.str.split('-').values, key=lambda x: (ordering_dict[x[2]], int(x[1]), x[0]))],:]

# %%
# plt.figure(figsize=(20,15))
# sns.clustermap(df_de, figsize=(20,15));

# %%
# sns.clustermap(df_de_ordered, figsize=(20,10), row_cluster=False, standard_scale=1);

# %%
# linkage_df = df_de_ordered.T.copy()

# linkage_df = linkage_df.subtract(linkage_df.min(1), axis=0)
# linkage_df = linkage_df.divide(linkage_df.max(1), axis=0)

# %% [markdown]
# Better to separately make the linkage matrix, becuase I'm going to want to cluster the genes based on it.

# %%
Z = scipy.cluster.hierarchy.linkage(df_de_ordered.T, method='average', optimal_ordering=True)

# %% [markdown]
# Gotta love scanpy's colors:

# %%
num_modules = 100
color_dict = dict(zip(range(num_modules),sc.pl.palettes.default_102))

# %%
modules = scipy.cluster.hierarchy.cut_tree(Z, num_modules).flatten()
sns.clustermap(df_de_ordered, figsize=(20,7), 
               row_cluster=False,
               col_linkage=Z, 
               col_colors=list(map(lambda x: color_dict[x], modules)),
               dendrogram_ratio=0.1,
              );

# %% [markdown]
# Extract out gene names from the modules and get better coloring.

# %%
# credit to user Has QUIT--Anony-Mousse from https://stackoverflow.com/questions/12572436/calculate-ordering-of-dendrogram-leaves
n = len(Z) + 1
cache = dict()
for k in range(len(Z)):
    c1, c2 = int(Z[k][0]), int(Z[k][1])
    c1 = [c1] if c1 < n else cache.pop(c1)
    c2 = [c2] if c2 < n else cache.pop(c2)
    cache[n+k] = c1 + c2
ordering = cache[2*len(Z)]

# %%
# cmap = mpl.cm.get_cmap('prism')

# %%
modules = scipy.cluster.hierarchy.cut_tree(Z, num_modules).flatten()[ordering]

# %%
module_vals, module_counts = np.unique(modules, return_counts=True)

# %%
modules_size_ordered = pd.DataFrame(data=zip(module_vals, module_counts),
                                    columns=['v','c']).sort_values('c', ascending=False)['v'].values

# %%
color_dict = dict(zip(modules_size_ordered,sc.pl.palettes.default_20*int(np.ceil(num_modules/len(sc.pl.palettes.default_20)))))
genes = df_de_ordered.columns.values[ordering]
cg = sns.clustermap(df_de_ordered[genes], figsize=(20,7), 
                    row_cluster=False,
                    col_cluster=False,
                    col_linkage=Z, 
                    col_colors=list(map(lambda x: color_dict[x], modules)),
                   );
cg.ax_heatmap.set_yticklabels([])
cg.ax_heatmap.set_yticks([])
cg.ax_heatmap.set_xticklabels([])
cg.ax_heatmap.set_xticks([]);

# %% [markdown]
# #### Module Identification

# %%
plt.figure(figsize=(10,3))
plt.bar(module_vals, module_counts);#, s=5);
plt.yscale('log');

# %%
plt.hist(module_counts, bins=np.logspace(np.log10(1), np.log10(500), 20));
plt.xscale('log')
plt.xlabel('Number of genes in a given module')
plt.ylabel('Density of modules');

# %% [markdown]
# Only want to keep the main modules:

# %%
main_modules = np.arange(num_modules)[module_counts > 5]
main_modules_genes = dict()
for module in main_modules:
    main_modules_genes[module] = genes[modules == module]

# %%
len(main_modules_genes)
# Out:
# 16

# %% [markdown]
# Visualize the colors for the modules.

# %%
plt.figure(figsize=(20,1))
plt.scatter(list(main_modules), [1]*len(main_modules), c=list(map(mpl.colors.hex2color, map(lambda x: color_dict[x], main_modules))), s=80);
plt.xticks(range(max(main_modules) + 3))
plt.yticks([]);

# %% [markdown]
# ### KMeans Clustering

# %% [markdown]
# When I started playing with making the equivalent heatmap for the single-cell data, I realized that KMeans actually works really well, and the clusters are all well-sized (i.e. no clusters with a single gene). So I decided to do that here:

# %%
from sklearn.cluster import KMeans
from sklearn import metrics
from scipy.spatial.distance import cdist

# %% [markdown]
# Code for finding optimal k taken from [here](https://pythonprogramminglanguage.com/kmeans-elbow-method/).

# %%
df_de_ordered.shape
# Out:
# (75, 1229)

# %% [markdown]
# distortions = list()
# K = np.concatenate(([1],np.arange(10,210,10)))
# for k in tqdm(K):
#     kmeanModel = KMeans(n_clusters=k).fit(df_de_ordered.T)
#     kmeanModel.fit(df_de.T)
#     distortions.append(sum(np.min(cdist(df_de_ordered.T, kmeanModel.cluster_centers_, 'euclidean'), axis=1)) / df_de_ordered.T.shape[0])

# %%
rise = [distortions[i] - distortions[i - 1] for i in range(1, len(K))]
run = [K[i] - K[i - 1] for i in range(1, len(K))]
slopes = np.array([-i/j for i, j in zip(rise, run)])

# %%
# Plot the elbow
fig, ax = plt.subplots(2, 1, figsize=(6,6))
ax[0].plot(K, distortions - min(distortions) + 1, 'bx-')
ax[0].set_ylabel('Distortion')
ax[0].set_yscale('log')
ax[1].bar(K[1:], slopes, width=4, color='k', alpha=0.5)
ax[1].set_ylabel('Slopes');

# %%
n_clusts = 30
kmeans = KMeans(n_clusters=n_clusts).fit(df_de.T)

# %%
# with open(prefix + 'kmeans.modules/kmeans.n30.out.pkl', 'wb') as file:
#     pkl.dump(kmeans, file)

# %%
with open(prefix + 'kmeans.modules/kmeans.n30.out.pkl', 'rb') as file:
    kmeans = pkl.load(file)

# %% [markdown]
# Gotta love scanpy's colors:

# %%
color_dict = dict(zip(range(n_clusts),sc.pl.palettes.default_20*2))

# %%
cg = sns.clustermap(df_de_ordered.iloc[:,np.argsort(kmeans.labels_)], figsize=(20,20), 
                    row_cluster=False,
                    col_cluster=False,
                    col_colors=list(map(lambda x: color_dict[x], np.sort(kmeans.labels_))),
                    dendrogram_ratio=0.1,
                   );
# plt.tight_layout()

# %%
ordered_conds = [i.split('-')[2] for i in df_de_ordered.index]
ordered_times = [i.split('-')[1] for i in df_de_ordered.index] # convert to int to get good order

# %%
times = np.unique([int(i) for i in ordered_times])

# %%
cmap = mpl.cm.get_cmap('gray', len(times) + 2)
time_colors = dict(zip([str(i) for i in times], # convert back to a string
                       [mpl.colors.rgb2hex(cmap(i)[:3]) for i in range(1,cmap.N - 1)[::-1]]))

# %%
with open(prefix + '../production.run/cond.colors.pkl', 'rb') as file:
    cond_colors = pkl.load(file)['hex']

# %%
cond_dict = {'TNFa': 'A',
             'R848': 'R',
             'PMAI': 'P',
             'IFNG': 'G',
             'IFNB': 'B',
             'Control': 'C'
            }

# %%
cond_colors['N'] = cond_colors['0']
cond_dict['None'] = 'N'

# %%
cg = sns.clustermap(df_de_ordered.iloc[:,np.argsort(kmeans.labels_)], figsize=(15,6), 
                    row_cluster=False,
                    col_cluster=False,
                    col_colors=list(map(lambda x: color_dict[x], np.sort(kmeans.labels_))),
                    row_colors=[list(map(lambda x: cond_colors[cond_dict[x]], ordered_conds)),
                                list(map(lambda x: time_colors[x], ordered_times))],
                    dendrogram_ratio=0.07,
                    cbar_pos=None);
cg.ax_heatmap.set_yticklabels([])
cg.ax_heatmap.set_yticks([])
cg.ax_heatmap.set_xticklabels([])
cg.ax_heatmap.set_xticks([]);

# %%
main_modules = np.arange(n_clusts)
main_modules_genes = dict(zip(main_modules, [df_de.columns[kmeans.labels_ == i].values for i in range(n_clusts)]))

# %%
plt.figure(figsize=(10,1))
plt.scatter(list(main_modules.astype(str)), [1]*len(main_modules), c=list(map(mpl.colors.hex2color, map(lambda x: color_dict[x], main_modules))), s=80);
plt.yticks([]);

# %%
# with open(prefix + 'kmeans.modules/kmeans.n30.main.modules.genes.pkl', 'wb') as file:
#     pkl.dump(main_modules_genes, file)

# %%
with open(prefix + 'kmeans.modules/kmeans.n30.main.modules.genes.pkl', 'rb') as file:
    main_modules_genes = pkl.load(file)

# %% [markdown]
# ### Gene Ontology

# %% [markdown]
# Run gene ontology analyses on the modules:

# %%
obo_fname = download_go_basic_obo(prefix + "go-basic.obo")
fin_gene2go = download_ncbi_associations(prefix + 'gene2go')
# Out:
#   EXISTS: /data/codec/bulk.jan20/go-basic.obo
#   EXISTS: /data/codec/bulk.jan20/gene2go

# %%
obodag = GODag(prefix + "go-basic.obo")
# Out:
# /data/codec/bulk.jan20/go-basic.obo: fmt(1.2) rel(2020-02-21) 47,245 GO Terms

# %%
# Read NCBI's gene2go. Store annotations in a list of named tuples
objanno = Gene2GoReader(fin_gene2go, taxids=[9606])

# Get namespace2association where:
#    namespace is:
#        BP: biological_process               
#        MF: molecular_function
#        CC: cellular_component
#    assocation is a dict:
#        key: NCBI GeneID
#        value: A set of GO IDs associated with that gene
ns2assoc = objanno.get_ns2assc()

for nspc, id2gos in ns2assoc.items():
    print("{NS} {N:,} annotated human genes".format(NS=nspc, N=len(id2gos)))
# Out:
# HMS:0:00:04.207588 323,107 annotations, 19,649 genes, 18,246 GOs, 1 taxids READ: /data/codec/bulk.jan20/gene2go
# BP 17,541 annotated human genes
# MF 17,384 annotated human genes
# CC 18,648 annotated human genes

# %%
gene_ids = list(GeneID2nt_hum.keys())
symbol2geneid = dict(zip([GeneID2nt_hum[i].Symbol for i in gene_ids], [i for i in gene_ids]))

# %% [markdown]
# Next cell produces a lot of output, recommend collapsing it in notebook.

# %%
results = list()
percent_genes_in_annot = list()
for module in tqdm(main_modules_genes):
    ids = list()

    for i in main_modules_genes[module]:
        try:
            ids.append(symbol2geneid[i])
        except:
            continue
    percent_genes_in_annot.append(len(ids)/len(main_modules_genes[module]))
    
    goeaobj = GOEnrichmentStudyNS(
            GeneID2nt_hum.keys(), # List of human protein-coding genes
            ns2assoc, # geneid/GO associations
            obodag, # Ontologies
            propagate_counts = False,
            alpha = 0.05, # default significance cut-off
            methods = ['fdr_bh']) # defult multipletest correction method
    
    goea_results_all = goeaobj.run_study(ids)
    for i in goea_results_all:
        results.append([str(module), i.name, i.NS, -np.log10(i.p_fdr_bh)])
# Out:
# HBox(children=(FloatProgress(value=0.0, max=30.0), HTML(value='')))
# Load BP Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,711 of 20,913 population items found in association
#
# Load CC Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  85% 17,755 of 20,913 population items found in association
#
# Load MF Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,699 of 20,913 population items found in association
#
# Run BP Gene Ontology Analysis: current study set of 31 IDs ... 94%     29 of     31 study items found in association
# 100%     31 of     31 study items found in population(20913)
# Calculating 12,176 uncorrected p-values using fisher_scipy_stats
#   12,176 GO terms are associated with 16,711 of 20,913 population items
#      207 GO terms are associated with     29 of     31 study items
#   METHOD fdr_bh:
#        2 GO terms found significant (< 0.05=alpha) (  2 enriched +   0 purified): statsmodels fdr_bh
#       10 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 31 IDs ... 97%     30 of     31 study items found in association
# 100%     31 of     31 study items found in population(20913)
# Calculating 1,731 uncorrected p-values using fisher_scipy_stats
#    1,731 GO terms are associated with 17,755 of 20,913 population items
#       82 GO terms are associated with     30 of     31 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 31 IDs ... 87%     27 of     31 study items found in association
# 100%     31 of     31 study items found in population(20913)
# Calculating 4,158 uncorrected p-values using fisher_scipy_stats
#    4,158 GO terms are associated with 16,699 of 20,913 population items
#       64 GO terms are associated with     27 of     31 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Load BP Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,711 of 20,913 population items found in association
#
# Load CC Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  85% 17,755 of 20,913 population items found in association
#
# Load MF Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,699 of 20,913 population items found in association
#
# Run BP Gene Ontology Analysis: current study set of 90 IDs ... 93%     84 of     90 study items found in association
# 100%     90 of     90 study items found in population(20913)
# Calculating 12,176 uncorrected p-values using fisher_scipy_stats
#   12,176 GO terms are associated with 16,711 of 20,913 population items
#      506 GO terms are associated with     84 of     90 study items
#   METHOD fdr_bh:
#       29 GO terms found significant (< 0.05=alpha) ( 29 enriched +   0 purified): statsmodels fdr_bh
#       52 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 90 IDs ... 98%     88 of     90 study items found in association
# 100%     90 of     90 study items found in population(20913)
# Calculating 1,731 uncorrected p-values using fisher_scipy_stats
#    1,731 GO terms are associated with 17,755 of 20,913 population items
#      107 GO terms are associated with     88 of     90 study items
#   METHOD fdr_bh:
#        3 GO terms found significant (< 0.05=alpha) (  3 enriched +   0 purified): statsmodels fdr_bh
#       72 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 90 IDs ... 98%     88 of     90 study items found in association
# 100%     90 of     90 study items found in population(20913)
# Calculating 4,158 uncorrected p-values using fisher_scipy_stats
#    4,158 GO terms are associated with 16,699 of 20,913 population items
#      153 GO terms are associated with     88 of     90 study items
#   METHOD fdr_bh:
#        9 GO terms found significant (< 0.05=alpha) (  9 enriched +   0 purified): statsmodels fdr_bh
#       74 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Load BP Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,711 of 20,913 population items found in association
#
# Load CC Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  85% 17,755 of 20,913 population items found in association
#
# Load MF Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,699 of 20,913 population items found in association
#
# Run BP Gene Ontology Analysis: current study set of 34 IDs ... 91%     31 of     34 study items found in association
# 100%     34 of     34 study items found in population(20913)
# Calculating 12,176 uncorrected p-values using fisher_scipy_stats
#   12,176 GO terms are associated with 16,711 of 20,913 population items
#      369 GO terms are associated with     31 of     34 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 34 IDs ... 91%     31 of     34 study items found in association
# 100%     34 of     34 study items found in population(20913)
# Calculating 1,731 uncorrected p-values using fisher_scipy_stats
#    1,731 GO terms are associated with 17,755 of 20,913 population items
#       59 GO terms are associated with     31 of     34 study items
#   METHOD fdr_bh:
#        1 GO terms found significant (< 0.05=alpha) (  1 enriched +   0 purified): statsmodels fdr_bh
#       10 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 34 IDs ... 97%     33 of     34 study items found in association
# 100%     34 of     34 study items found in population(20913)
# Calculating 4,158 uncorrected p-values using fisher_scipy_stats
#    4,158 GO terms are associated with 16,699 of 20,913 population items
#       77 GO terms are associated with     33 of     34 study items
#   METHOD fdr_bh:
#        3 GO terms found significant (< 0.05=alpha) (  3 enriched +   0 purified): statsmodels fdr_bh
#       12 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Load BP Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,711 of 20,913 population items found in association
#
# Load CC Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  85% 17,755 of 20,913 population items found in association
#
# Load MF Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,699 of 20,913 population items found in association
#
# Run BP Gene Ontology Analysis: current study set of 49 IDs ... 94%     46 of     49 study items found in association
# 100%     49 of     49 study items found in population(20913)
# Calculating 12,176 uncorrected p-values using fisher_scipy_stats
#   12,176 GO terms are associated with 16,711 of 20,913 population items
#      547 GO terms are associated with     46 of     49 study items
#   METHOD fdr_bh:
#        5 GO terms found significant (< 0.05=alpha) (  5 enriched +   0 purified): statsmodels fdr_bh
#       15 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 49 IDs ... 98%     48 of     49 study items found in association
# 100%     49 of     49 study items found in population(20913)
# Calculating 1,731 uncorrected p-values using fisher_scipy_stats
#    1,731 GO terms are associated with 17,755 of 20,913 population items
#      117 GO terms are associated with     48 of     49 study items
#   METHOD fdr_bh:
#        1 GO terms found significant (< 0.05=alpha) (  1 enriched +   0 purified): statsmodels fdr_bh
#       27 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 49 IDs ... 98%     48 of     49 study items found in association
# 100%     49 of     49 study items found in population(20913)
# Calculating 4,158 uncorrected p-values using fisher_scipy_stats
#    4,158 GO terms are associated with 16,699 of 20,913 population items
#      176 GO terms are associated with     48 of     49 study items
#   METHOD fdr_bh:
#        1 GO terms found significant (< 0.05=alpha) (  1 enriched +   0 purified): statsmodels fdr_bh
#        2 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Load BP Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,711 of 20,913 population items found in association
#
# Load CC Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  85% 17,755 of 20,913 population items found in association
#
# Load MF Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,699 of 20,913 population items found in association
#
# Run BP Gene Ontology Analysis: current study set of 17 IDs ... 94%     16 of     17 study items found in association
# 100%     17 of     17 study items found in population(20913)
# Calculating 12,176 uncorrected p-values using fisher_scipy_stats
#   12,176 GO terms are associated with 16,711 of 20,913 population items
#      169 GO terms are associated with     16 of     17 study items
#   METHOD fdr_bh:
#        2 GO terms found significant (< 0.05=alpha) (  2 enriched +   0 purified): statsmodels fdr_bh
#        4 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 17 IDs ... 94%     16 of     17 study items found in association
# 100%     17 of     17 study items found in population(20913)
# Calculating 1,731 uncorrected p-values using fisher_scipy_stats
#    1,731 GO terms are associated with 17,755 of 20,913 population items
#       28 GO terms are associated with     16 of     17 study items
#   METHOD fdr_bh:
#        2 GO terms found significant (< 0.05=alpha) (  2 enriched +   0 purified): statsmodels fdr_bh
#       10 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 17 IDs ...100%     17 of     17 study items found in association
# 100%     17 of     17 study items found in population(20913)
# Calculating 4,158 uncorrected p-values using fisher_scipy_stats
#    4,158 GO terms are associated with 16,699 of 20,913 population items
#       48 GO terms are associated with     17 of     17 study items
#   METHOD fdr_bh:
#        1 GO terms found significant (< 0.05=alpha) (  1 enriched +   0 purified): statsmodels fdr_bh
#        3 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Load BP Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,711 of 20,913 population items found in association
#
# Load CC Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  85% 17,755 of 20,913 population items found in association
#
# Load MF Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,699 of 20,913 population items found in association
#
# Run BP Gene Ontology Analysis: current study set of 81 IDs ... 98%     79 of     81 study items found in association
# 100%     81 of     81 study items found in population(20913)
# Calculating 12,176 uncorrected p-values using fisher_scipy_stats
#   12,176 GO terms are associated with 16,711 of 20,913 population items
#      681 GO terms are associated with     79 of     81 study items
#   METHOD fdr_bh:
#        2 GO terms found significant (< 0.05=alpha) (  2 enriched +   0 purified): statsmodels fdr_bh
#       16 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 81 IDs ... 99%     80 of     81 study items found in association
# 100%     81 of     81 study items found in population(20913)
# Calculating 1,731 uncorrected p-values using fisher_scipy_stats
#    1,731 GO terms are associated with 17,755 of 20,913 population items
#      125 GO terms are associated with     80 of     81 study items
#   METHOD fdr_bh:
#        8 GO terms found significant (< 0.05=alpha) (  8 enriched +   0 purified): statsmodels fdr_bh
#       68 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 81 IDs ... 98%     79 of     81 study items found in association
# 100%     81 of     81 study items found in population(20913)
# Calculating 4,158 uncorrected p-values using fisher_scipy_stats
#    4,158 GO terms are associated with 16,699 of 20,913 population items
#      178 GO terms are associated with     79 of     81 study items
#   METHOD fdr_bh:
#        4 GO terms found significant (< 0.05=alpha) (  4 enriched +   0 purified): statsmodels fdr_bh
#       71 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Load BP Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,711 of 20,913 population items found in association
#
# Load CC Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  85% 17,755 of 20,913 population items found in association
#
# Load MF Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,699 of 20,913 population items found in association
#
# Run BP Gene Ontology Analysis: current study set of 23 IDs ... 96%     22 of     23 study items found in association
# 100%     23 of     23 study items found in population(20913)
# Calculating 12,176 uncorrected p-values using fisher_scipy_stats
#   12,176 GO terms are associated with 16,711 of 20,913 population items
#      255 GO terms are associated with     22 of     23 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 23 IDs ...100%     23 of     23 study items found in association
# 100%     23 of     23 study items found in population(20913)
# Calculating 1,731 uncorrected p-values using fisher_scipy_stats
#    1,731 GO terms are associated with 17,755 of 20,913 population items
#       52 GO terms are associated with     23 of     23 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 23 IDs ...100%     23 of     23 study items found in association
# 100%     23 of     23 study items found in population(20913)
# Calculating 4,158 uncorrected p-values using fisher_scipy_stats
#    4,158 GO terms are associated with 16,699 of 20,913 population items
#       44 GO terms are associated with     23 of     23 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Load BP Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,711 of 20,913 population items found in association
#
# Load CC Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  85% 17,755 of 20,913 population items found in association
#
# Load MF Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,699 of 20,913 population items found in association
#
# Run BP Gene Ontology Analysis: current study set of 28 IDs ... 93%     26 of     28 study items found in association
# 100%     28 of     28 study items found in population(20913)
# Calculating 12,176 uncorrected p-values using fisher_scipy_stats
#   12,176 GO terms are associated with 16,711 of 20,913 population items
#      290 GO terms are associated with     26 of     28 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 28 IDs ... 89%     25 of     28 study items found in association
# 100%     28 of     28 study items found in population(20913)
# Calculating 1,731 uncorrected p-values using fisher_scipy_stats
#    1,731 GO terms are associated with 17,755 of 20,913 population items
#       73 GO terms are associated with     25 of     28 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 28 IDs ... 96%     27 of     28 study items found in association
# 100%     28 of     28 study items found in population(20913)
# Calculating 4,158 uncorrected p-values using fisher_scipy_stats
#    4,158 GO terms are associated with 16,699 of 20,913 population items
#       73 GO terms are associated with     27 of     28 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Load BP Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,711 of 20,913 population items found in association
#
# Load CC Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  85% 17,755 of 20,913 population items found in association
#
# Load MF Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,699 of 20,913 population items found in association
#
# Run BP Gene Ontology Analysis: current study set of 34 IDs ... 94%     32 of     34 study items found in association
# 100%     34 of     34 study items found in population(20913)
# Calculating 12,176 uncorrected p-values using fisher_scipy_stats
#   12,176 GO terms are associated with 16,711 of 20,913 population items
#      353 GO terms are associated with     32 of     34 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 34 IDs ... 94%     32 of     34 study items found in association
# 100%     34 of     34 study items found in population(20913)
# Calculating 1,731 uncorrected p-values using fisher_scipy_stats
#    1,731 GO terms are associated with 17,755 of 20,913 population items
#       68 GO terms are associated with     32 of     34 study items
#   METHOD fdr_bh:
#        1 GO terms found significant (< 0.05=alpha) (  1 enriched +   0 purified): statsmodels fdr_bh
#       12 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 34 IDs ... 88%     30 of     34 study items found in association
# 100%     34 of     34 study items found in population(20913)
# Calculating 4,158 uncorrected p-values using fisher_scipy_stats
#    4,158 GO terms are associated with 16,699 of 20,913 population items
#       68 GO terms are associated with     30 of     34 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Load BP Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,711 of 20,913 population items found in association
#
# Load CC Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  85% 17,755 of 20,913 population items found in association
#
# Load MF Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,699 of 20,913 population items found in association
#
# Run BP Gene Ontology Analysis: current study set of 24 IDs ... 92%     22 of     24 study items found in association
# 100%     24 of     24 study items found in population(20913)
# Calculating 12,176 uncorrected p-values using fisher_scipy_stats
#   12,176 GO terms are associated with 16,711 of 20,913 population items
#      210 GO terms are associated with     22 of     24 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 24 IDs ... 92%     22 of     24 study items found in association
# 100%     24 of     24 study items found in population(20913)
# Calculating 1,731 uncorrected p-values using fisher_scipy_stats
#    1,731 GO terms are associated with 17,755 of 20,913 population items
#       60 GO terms are associated with     22 of     24 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 24 IDs ... 96%     23 of     24 study items found in association
# 100%     24 of     24 study items found in population(20913)
# Calculating 4,158 uncorrected p-values using fisher_scipy_stats
#    4,158 GO terms are associated with 16,699 of 20,913 population items
#       71 GO terms are associated with     23 of     24 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Load BP Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,711 of 20,913 population items found in association
#
# Load CC Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  85% 17,755 of 20,913 population items found in association
#
# Load MF Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,699 of 20,913 population items found in association
#
# Run BP Gene Ontology Analysis: current study set of 20 IDs ... 95%     19 of     20 study items found in association
# 100%     20 of     20 study items found in population(20913)
# Calculating 12,176 uncorrected p-values using fisher_scipy_stats
#   12,176 GO terms are associated with 16,711 of 20,913 population items
#      247 GO terms are associated with     19 of     20 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 20 IDs ...100%     20 of     20 study items found in association
# 100%     20 of     20 study items found in population(20913)
# Calculating 1,731 uncorrected p-values using fisher_scipy_stats
#    1,731 GO terms are associated with 17,755 of 20,913 population items
#       89 GO terms are associated with     20 of     20 study items
#   METHOD fdr_bh:
#        1 GO terms found significant (< 0.05=alpha) (  1 enriched +   0 purified): statsmodels fdr_bh
#        2 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 20 IDs ... 95%     19 of     20 study items found in association
# 100%     20 of     20 study items found in population(20913)
# Calculating 4,158 uncorrected p-values using fisher_scipy_stats
#    4,158 GO terms are associated with 16,699 of 20,913 population items
#       60 GO terms are associated with     19 of     20 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Load BP Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,711 of 20,913 population items found in association
#
# Load CC Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  85% 17,755 of 20,913 population items found in association
#
# Load MF Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,699 of 20,913 population items found in association
#
# Run BP Gene Ontology Analysis: current study set of 26 IDs ... 96%     25 of     26 study items found in association
# 100%     26 of     26 study items found in population(20913)
# Calculating 12,176 uncorrected p-values using fisher_scipy_stats
#   12,176 GO terms are associated with 16,711 of 20,913 population items
#      353 GO terms are associated with     25 of     26 study items
#   METHOD fdr_bh:
#        6 GO terms found significant (< 0.05=alpha) (  6 enriched +   0 purified): statsmodels fdr_bh
#       12 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 26 IDs ...100%     26 of     26 study items found in association
# 100%     26 of     26 study items found in population(20913)
# Calculating 1,731 uncorrected p-values using fisher_scipy_stats
#    1,731 GO terms are associated with 17,755 of 20,913 population items
#       55 GO terms are associated with     26 of     26 study items
#   METHOD fdr_bh:
#        1 GO terms found significant (< 0.05=alpha) (  1 enriched +   0 purified): statsmodels fdr_bh
#        2 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 26 IDs ...100%     26 of     26 study items found in association
# 100%     26 of     26 study items found in population(20913)
# Calculating 4,158 uncorrected p-values using fisher_scipy_stats
#    4,158 GO terms are associated with 16,699 of 20,913 population items
#      100 GO terms are associated with     26 of     26 study items
#   METHOD fdr_bh:
#        2 GO terms found significant (< 0.05=alpha) (  2 enriched +   0 purified): statsmodels fdr_bh
#        8 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Load BP Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,711 of 20,913 population items found in association
#
# Load CC Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  85% 17,755 of 20,913 population items found in association
#
# Load MF Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,699 of 20,913 population items found in association
#
# Run BP Gene Ontology Analysis: current study set of 28 IDs ... 82%     23 of     28 study items found in association
# 100%     28 of     28 study items found in population(20913)
# Calculating 12,176 uncorrected p-values using fisher_scipy_stats
#   12,176 GO terms are associated with 16,711 of 20,913 population items
#      151 GO terms are associated with     23 of     28 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 28 IDs ... 82%     23 of     28 study items found in association
# 100%     28 of     28 study items found in population(20913)
# Calculating 1,731 uncorrected p-values using fisher_scipy_stats
#    1,731 GO terms are associated with 17,755 of 20,913 population items
#       44 GO terms are associated with     23 of     28 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 28 IDs ... 79%     22 of     28 study items found in association
# 100%     28 of     28 study items found in population(20913)
# Calculating 4,158 uncorrected p-values using fisher_scipy_stats
#    4,158 GO terms are associated with 16,699 of 20,913 population items
#       58 GO terms are associated with     22 of     28 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Load BP Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,711 of 20,913 population items found in association
#
# Load CC Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  85% 17,755 of 20,913 population items found in association
#
# Load MF Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,699 of 20,913 population items found in association
#
# Run BP Gene Ontology Analysis: current study set of 31 IDs ... 94%     29 of     31 study items found in association
# 100%     31 of     31 study items found in population(20913)
# Calculating 12,176 uncorrected p-values using fisher_scipy_stats
#   12,176 GO terms are associated with 16,711 of 20,913 population items
#      355 GO terms are associated with     29 of     31 study items
#   METHOD fdr_bh:
#        2 GO terms found significant (< 0.05=alpha) (  2 enriched +   0 purified): statsmodels fdr_bh
#        8 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 31 IDs ... 94%     29 of     31 study items found in association
# 100%     31 of     31 study items found in population(20913)
# Calculating 1,731 uncorrected p-values using fisher_scipy_stats
#    1,731 GO terms are associated with 17,755 of 20,913 population items
#       58 GO terms are associated with     29 of     31 study items
#   METHOD fdr_bh:
#        1 GO terms found significant (< 0.05=alpha) (  1 enriched +   0 purified): statsmodels fdr_bh
#       11 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 31 IDs ... 97%     30 of     31 study items found in association
# 100%     31 of     31 study items found in population(20913)
# Calculating 4,158 uncorrected p-values using fisher_scipy_stats
#    4,158 GO terms are associated with 16,699 of 20,913 population items
#       82 GO terms are associated with     30 of     31 study items
#   METHOD fdr_bh:
#        1 GO terms found significant (< 0.05=alpha) (  1 enriched +   0 purified): statsmodels fdr_bh
#        5 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Load BP Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,711 of 20,913 population items found in association
#
# Load CC Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  85% 17,755 of 20,913 population items found in association
#
# Load MF Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,699 of 20,913 population items found in association
#
# Run BP Gene Ontology Analysis: current study set of 66 IDs ... 89%     59 of     66 study items found in association
# 100%     66 of     66 study items found in population(20913)
# Calculating 12,176 uncorrected p-values using fisher_scipy_stats
#   12,176 GO terms are associated with 16,711 of 20,913 population items
#      673 GO terms are associated with     59 of     66 study items
#   METHOD fdr_bh:
#        6 GO terms found significant (< 0.05=alpha) (  6 enriched +   0 purified): statsmodels fdr_bh
#       25 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 66 IDs ... 98%     65 of     66 study items found in association
# 100%     66 of     66 study items found in population(20913)
# Calculating 1,731 uncorrected p-values using fisher_scipy_stats
#    1,731 GO terms are associated with 17,755 of 20,913 population items
#      141 GO terms are associated with     65 of     66 study items
#   METHOD fdr_bh:
#        7 GO terms found significant (< 0.05=alpha) (  7 enriched +   0 purified): statsmodels fdr_bh
#       47 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 66 IDs ... 91%     60 of     66 study items found in association
# 100%     66 of     66 study items found in population(20913)
# Calculating 4,158 uncorrected p-values using fisher_scipy_stats
#    4,158 GO terms are associated with 16,699 of 20,913 population items
#      178 GO terms are associated with     60 of     66 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Load BP Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,711 of 20,913 population items found in association
#
# Load CC Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  85% 17,755 of 20,913 population items found in association
#
# Load MF Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,699 of 20,913 population items found in association
#
# Run BP Gene Ontology Analysis: current study set of 46 IDs ... 96%     44 of     46 study items found in association
# 100%     46 of     46 study items found in population(20913)
# Calculating 12,176 uncorrected p-values using fisher_scipy_stats
#   12,176 GO terms are associated with 16,711 of 20,913 population items
#      402 GO terms are associated with     44 of     46 study items
#   METHOD fdr_bh:
#       10 GO terms found significant (< 0.05=alpha) ( 10 enriched +   0 purified): statsmodels fdr_bh
#       18 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 46 IDs ... 96%     44 of     46 study items found in association
# 100%     46 of     46 study items found in population(20913)
# Calculating 1,731 uncorrected p-values using fisher_scipy_stats
#    1,731 GO terms are associated with 17,755 of 20,913 population items
#       88 GO terms are associated with     44 of     46 study items
#   METHOD fdr_bh:
#        5 GO terms found significant (< 0.05=alpha) (  5 enriched +   0 purified): statsmodels fdr_bh
#       10 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 46 IDs ... 98%     45 of     46 study items found in association
# 100%     46 of     46 study items found in population(20913)
# Calculating 4,158 uncorrected p-values using fisher_scipy_stats
#    4,158 GO terms are associated with 16,699 of 20,913 population items
#      124 GO terms are associated with     45 of     46 study items
#   METHOD fdr_bh:
#        6 GO terms found significant (< 0.05=alpha) (  6 enriched +   0 purified): statsmodels fdr_bh
#        6 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Load BP Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,711 of 20,913 population items found in association
#
# Load CC Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  85% 17,755 of 20,913 population items found in association
#
# Load MF Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,699 of 20,913 population items found in association
#
# Run BP Gene Ontology Analysis: current study set of 26 IDs ... 96%     25 of     26 study items found in association
# 100%     26 of     26 study items found in population(20913)
# Calculating 12,176 uncorrected p-values using fisher_scipy_stats
#   12,176 GO terms are associated with 16,711 of 20,913 population items
#      328 GO terms are associated with     25 of     26 study items
#   METHOD fdr_bh:
#        6 GO terms found significant (< 0.05=alpha) (  6 enriched +   0 purified): statsmodels fdr_bh
#        4 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 26 IDs ... 96%     25 of     26 study items found in association
# 100%     26 of     26 study items found in population(20913)
# Calculating 1,731 uncorrected p-values using fisher_scipy_stats
#    1,731 GO terms are associated with 17,755 of 20,913 population items
#       65 GO terms are associated with     25 of     26 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 26 IDs ...100%     26 of     26 study items found in association
# 100%     26 of     26 study items found in population(20913)
# Calculating 4,158 uncorrected p-values using fisher_scipy_stats
#    4,158 GO terms are associated with 16,699 of 20,913 population items
#       89 GO terms are associated with     26 of     26 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Load BP Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,711 of 20,913 population items found in association
#
# Load CC Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  85% 17,755 of 20,913 population items found in association
#
# Load MF Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,699 of 20,913 population items found in association
#
# Run BP Gene Ontology Analysis: current study set of 25 IDs ...100%     25 of     25 study items found in association
# 100%     25 of     25 study items found in population(20913)
# Calculating 12,176 uncorrected p-values using fisher_scipy_stats
#   12,176 GO terms are associated with 16,711 of 20,913 population items
#      323 GO terms are associated with     25 of     25 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 25 IDs ...100%     25 of     25 study items found in association
# 100%     25 of     25 study items found in population(20913)
# Calculating 1,731 uncorrected p-values using fisher_scipy_stats
#    1,731 GO terms are associated with 17,755 of 20,913 population items
#       70 GO terms are associated with     25 of     25 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 25 IDs ... 88%     22 of     25 study items found in association
# 100%     25 of     25 study items found in population(20913)
# Calculating 4,158 uncorrected p-values using fisher_scipy_stats
#    4,158 GO terms are associated with 16,699 of 20,913 population items
#       92 GO terms are associated with     22 of     25 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Load BP Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,711 of 20,913 population items found in association
#
# Load CC Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  85% 17,755 of 20,913 population items found in association
#
# Load MF Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,699 of 20,913 population items found in association
#
# Run BP Gene Ontology Analysis: current study set of 67 IDs ... 90%     60 of     67 study items found in association
# 100%     67 of     67 study items found in population(20913)
# Calculating 12,176 uncorrected p-values using fisher_scipy_stats
#   12,176 GO terms are associated with 16,711 of 20,913 population items
#      397 GO terms are associated with     60 of     67 study items
#   METHOD fdr_bh:
#        8 GO terms found significant (< 0.05=alpha) (  8 enriched +   0 purified): statsmodels fdr_bh
#       19 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 67 IDs ... 93%     62 of     67 study items found in association
# 100%     67 of     67 study items found in population(20913)
# Calculating 1,731 uncorrected p-values using fisher_scipy_stats
#    1,731 GO terms are associated with 17,755 of 20,913 population items
#      119 GO terms are associated with     62 of     67 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 67 IDs ... 85%     57 of     67 study items found in association
# 100%     67 of     67 study items found in population(20913)
# Calculating 4,158 uncorrected p-values using fisher_scipy_stats
#    4,158 GO terms are associated with 16,699 of 20,913 population items
#      142 GO terms are associated with     57 of     67 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Load BP Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,711 of 20,913 population items found in association
#
# Load CC Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  85% 17,755 of 20,913 population items found in association
#
# Load MF Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,699 of 20,913 population items found in association
#
# Run BP Gene Ontology Analysis: current study set of 26 IDs ...100%     26 of     26 study items found in association
# 100%     26 of     26 study items found in population(20913)
# Calculating 12,176 uncorrected p-values using fisher_scipy_stats
#   12,176 GO terms are associated with 16,711 of 20,913 population items
#      295 GO terms are associated with     26 of     26 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 26 IDs ...100%     26 of     26 study items found in association
# 100%     26 of     26 study items found in population(20913)
# Calculating 1,731 uncorrected p-values using fisher_scipy_stats
#    1,731 GO terms are associated with 17,755 of 20,913 population items
#       56 GO terms are associated with     26 of     26 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 26 IDs ... 96%     25 of     26 study items found in association
# 100%     26 of     26 study items found in population(20913)
# Calculating 4,158 uncorrected p-values using fisher_scipy_stats
#    4,158 GO terms are associated with 16,699 of 20,913 population items
#       99 GO terms are associated with     25 of     26 study items
#   METHOD fdr_bh:
# ...
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 58 IDs ... 97%     56 of     58 study items found in association
# 100%     58 of     58 study items found in population(20913)
# Calculating 1,731 uncorrected p-values using fisher_scipy_stats
#    1,731 GO terms are associated with 17,755 of 20,913 population items
#      101 GO terms are associated with     56 of     58 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 58 IDs ... 98%     57 of     58 study items found in association
# 100%     58 of     58 study items found in population(20913)
# Calculating 4,158 uncorrected p-values using fisher_scipy_stats
#    4,158 GO terms are associated with 16,699 of 20,913 population items
#      164 GO terms are associated with     57 of     58 study items
#   METHOD fdr_bh:
#        1 GO terms found significant (< 0.05=alpha) (  1 enriched +   0 purified): statsmodels fdr_bh
#       45 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Load BP Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,711 of 20,913 population items found in association
#
# Load CC Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  85% 17,755 of 20,913 population items found in association
#
# Load MF Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,699 of 20,913 population items found in association
#
# Run BP Gene Ontology Analysis: current study set of 24 IDs ... 92%     22 of     24 study items found in association
# 100%     24 of     24 study items found in population(20913)
# Calculating 12,176 uncorrected p-values using fisher_scipy_stats
#   12,176 GO terms are associated with 16,711 of 20,913 population items
#      248 GO terms are associated with     22 of     24 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 24 IDs ... 92%     22 of     24 study items found in association
# 100%     24 of     24 study items found in population(20913)
# Calculating 1,731 uncorrected p-values using fisher_scipy_stats
#    1,731 GO terms are associated with 17,755 of 20,913 population items
#       53 GO terms are associated with     22 of     24 study items
#   METHOD fdr_bh:
#        1 GO terms found significant (< 0.05=alpha) (  1 enriched +   0 purified): statsmodels fdr_bh
#        3 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 24 IDs ... 92%     22 of     24 study items found in association
# 100%     24 of     24 study items found in population(20913)
# Calculating 4,158 uncorrected p-values using fisher_scipy_stats
#    4,158 GO terms are associated with 16,699 of 20,913 population items
#       67 GO terms are associated with     22 of     24 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Load BP Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,711 of 20,913 population items found in association
#
# Load CC Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  85% 17,755 of 20,913 population items found in association
#
# Load MF Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,699 of 20,913 population items found in association
#
# Run BP Gene Ontology Analysis: current study set of 16 IDs ... 81%     13 of     16 study items found in association
# 100%     16 of     16 study items found in population(20913)
# Calculating 12,176 uncorrected p-values using fisher_scipy_stats
#   12,176 GO terms are associated with 16,711 of 20,913 population items
#       78 GO terms are associated with     13 of     16 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 16 IDs ... 81%     13 of     16 study items found in association
# 100%     16 of     16 study items found in population(20913)
# Calculating 1,731 uncorrected p-values using fisher_scipy_stats
#    1,731 GO terms are associated with 17,755 of 20,913 population items
#       39 GO terms are associated with     13 of     16 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 16 IDs ... 94%     15 of     16 study items found in association
# 100%     16 of     16 study items found in population(20913)
# Calculating 4,158 uncorrected p-values using fisher_scipy_stats
#    4,158 GO terms are associated with 16,699 of 20,913 population items
#       35 GO terms are associated with     15 of     16 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Load BP Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,711 of 20,913 population items found in association
#
# Load CC Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  85% 17,755 of 20,913 population items found in association
#
# Load MF Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,699 of 20,913 population items found in association
#
# Run BP Gene Ontology Analysis: current study set of 17 IDs ... 94%     16 of     17 study items found in association
# 100%     17 of     17 study items found in population(20913)
# Calculating 12,176 uncorrected p-values using fisher_scipy_stats
#   12,176 GO terms are associated with 16,711 of 20,913 population items
#      106 GO terms are associated with     16 of     17 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 17 IDs ... 94%     16 of     17 study items found in association
# 100%     17 of     17 study items found in population(20913)
# Calculating 1,731 uncorrected p-values using fisher_scipy_stats
#    1,731 GO terms are associated with 17,755 of 20,913 population items
#       70 GO terms are associated with     16 of     17 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 17 IDs ... 94%     16 of     17 study items found in association
# 100%     17 of     17 study items found in population(20913)
# Calculating 4,158 uncorrected p-values using fisher_scipy_stats
#    4,158 GO terms are associated with 16,699 of 20,913 population items
#       42 GO terms are associated with     16 of     17 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Load BP Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,711 of 20,913 population items found in association
#
# Load CC Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  85% 17,755 of 20,913 population items found in association
#
# Load MF Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,699 of 20,913 population items found in association
#
# Run BP Gene Ontology Analysis: current study set of 27 IDs ... 89%     24 of     27 study items found in association
# 100%     27 of     27 study items found in population(20913)
# Calculating 12,176 uncorrected p-values using fisher_scipy_stats
#   12,176 GO terms are associated with 16,711 of 20,913 population items
#      202 GO terms are associated with     24 of     27 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 27 IDs ... 96%     26 of     27 study items found in association
# 100%     27 of     27 study items found in population(20913)
# Calculating 1,731 uncorrected p-values using fisher_scipy_stats
#    1,731 GO terms are associated with 17,755 of 20,913 population items
#       62 GO terms are associated with     26 of     27 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 27 IDs ... 89%     24 of     27 study items found in association
# 100%     27 of     27 study items found in population(20913)
# Calculating 4,158 uncorrected p-values using fisher_scipy_stats
#    4,158 GO terms are associated with 16,699 of 20,913 population items
#       52 GO terms are associated with     24 of     27 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Load BP Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,711 of 20,913 population items found in association
#
# Load CC Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  85% 17,755 of 20,913 population items found in association
#
# Load MF Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,699 of 20,913 population items found in association
#
# Run BP Gene Ontology Analysis: current study set of 25 IDs ... 96%     24 of     25 study items found in association
# 100%     25 of     25 study items found in population(20913)
# Calculating 12,176 uncorrected p-values using fisher_scipy_stats
#   12,176 GO terms are associated with 16,711 of 20,913 population items
#      472 GO terms are associated with     24 of     25 study items
#   METHOD fdr_bh:
#       38 GO terms found significant (< 0.05=alpha) ( 38 enriched +   0 purified): statsmodels fdr_bh
#       18 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 25 IDs ... 96%     24 of     25 study items found in association
# 100%     25 of     25 study items found in population(20913)
# Calculating 1,731 uncorrected p-values using fisher_scipy_stats
#    1,731 GO terms are associated with 17,755 of 20,913 population items
#       51 GO terms are associated with     24 of     25 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 25 IDs ... 92%     23 of     25 study items found in association
# 100%     25 of     25 study items found in population(20913)
# Calculating 4,158 uncorrected p-values using fisher_scipy_stats
#    4,158 GO terms are associated with 16,699 of 20,913 population items
#       81 GO terms are associated with     23 of     25 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Load BP Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,711 of 20,913 population items found in association
#
# Load CC Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  85% 17,755 of 20,913 population items found in association
#
# Load MF Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,699 of 20,913 population items found in association
#
# Run BP Gene Ontology Analysis: current study set of 39 IDs ... 97%     38 of     39 study items found in association
# 100%     39 of     39 study items found in population(20913)
# Calculating 12,176 uncorrected p-values using fisher_scipy_stats
#   12,176 GO terms are associated with 16,711 of 20,913 population items
#      342 GO terms are associated with     38 of     39 study items
#   METHOD fdr_bh:
#        5 GO terms found significant (< 0.05=alpha) (  5 enriched +   0 purified): statsmodels fdr_bh
#        9 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 39 IDs ... 97%     38 of     39 study items found in association
# 100%     39 of     39 study items found in population(20913)
# Calculating 1,731 uncorrected p-values using fisher_scipy_stats
#    1,731 GO terms are associated with 17,755 of 20,913 population items
#      112 GO terms are associated with     38 of     39 study items
#   METHOD fdr_bh:
#       11 GO terms found significant (< 0.05=alpha) ( 11 enriched +   0 purified): statsmodels fdr_bh
#       28 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 39 IDs ... 97%     38 of     39 study items found in association
# 100%     39 of     39 study items found in population(20913)
# Calculating 4,158 uncorrected p-values using fisher_scipy_stats
#    4,158 GO terms are associated with 16,699 of 20,913 population items
#      104 GO terms are associated with     38 of     39 study items
#   METHOD fdr_bh:
#        3 GO terms found significant (< 0.05=alpha) (  3 enriched +   0 purified): statsmodels fdr_bh
#        6 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)

# %%
results_df = pd.DataFrame(results, columns=['Module', 'GO_term', 'GO_type', '-log10padj'])

# %%
results_df['Module'] = results_df['Module'].astype(np.int)

# %%
# with open(prefix + 'kmeans.modules/kmeans.n30.results_df.pkl', 'wb') as file:
#     pkl.dump(results_df, file)

# %%
with open(prefix + 'kmeans.modules/kmeans.n30.results_df.pkl', 'rb') as file:
    results_df = pkl.load(file)

# %% [markdown]
# Visualize the significance levels for the terms found in enriched in each module. BP = biological process, MF = molecular function, CC = cellular component.

# %%
plt.figure(figsize=(15,4))
sns.stripplot(data=results_df,x='Module', hue='GO_type', y='-log10padj', dodge=True, size=2);
plt.plot([-0.5,len(main_modules) - 0.5],[-np.log10(0.05)]*2, linestyle='--', linewidth=1, color='r');

# %% [markdown]
# Is the lack of significance from some modules due to the fact that the gene names from that module did not exactly match gene names in the gene ontology dictionary?

# %%
plt.figure(figsize=(12,4))
plt.bar([str(i) for i in main_modules], percent_genes_in_annot);

# %% [markdown]
# I think at least 60% of genes is okay.

# %%
plt.figure(figsize=(10,1))
plt.scatter(list(main_modules.astype(str)), [1]*len(main_modules), c=list(map(mpl.colors.hex2color, map(lambda x: color_dict[x], main_modules))), s=80);
plt.yticks([]);

# %% [markdown]
# ### Print out and Explore GO Analysis Results

# %%
from IPython.display import display # need this to print out the results without truncation.

# %%
sig_dfs = dict()
for module in main_modules:
    df = results_df[(results_df['-log10padj'] > -np.log10(0.05)) &
                (results_df['Module'] == module)
               ][['GO_type', 'GO_term', '-log10padj']].sort_values(['GO_type', '-log10padj'], ascending=False)
    sig_dfs[module] = df.copy()

# %%
for module in sig_dfs:
    print((module, len(sig_dfs[module])))
# Out:
# (0, 2)
# (1, 41)
# (2, 4)
# (3, 7)
# (4, 5)
# (5, 14)
# (6, 0)
# (7, 0)
# (8, 1)
# (9, 0)
# (10, 1)
# (11, 9)
# (12, 0)
# (13, 4)
# (14, 13)
# (15, 21)
# (16, 6)
# (17, 0)
# (18, 8)
# (19, 0)
# (20, 41)
# (21, 2)
# (22, 47)
# (23, 1)
# (24, 1)
# (25, 0)
# (26, 0)
# (27, 0)
# (28, 38)
# (29, 19)

# %%
sig_modules = [1, 2, 3, 4, 5, 11, 14, 15, 16, 18, 20, 22, 28, 29]

# %%
len(sig_modules)
# Out:
# 14

# %%
module = 25
with pd.option_context('display.max_rows', 150, 'display.max_columns', 10, 'display.max_colwidth', -1):
    display(results_df[(results_df['Module'] == module) & (results_df['GO_type'] == 'MF')].sort_values('-log10padj', ascending=False).head(5))
    display(results_df[(results_df['Module'] == module) & (results_df['GO_type'] == 'CC')].sort_values('-log10padj', ascending=False).head(5))
    display(results_df[(results_df['Module'] == module) & (results_df['GO_type'] == 'BP')].sort_values('-log10padj', ascending=False).head(5))
# Out:
#         Module                                               GO_term GO_type  \
# 465532  25      arachidonate 8(S)-lipoxygenase activity               MF
# 468325  25      rRNA (adenine-N6,N6-)-dimethyltransferase activity    MF
# 468295  25      long-chain-alcohol oxidase activity                   MF
# 468296  25      enzyme binding                                        MF
# 468297  25      histone acetyltransferase activity (H4-K16 specific)  MF
#
#         -log10padj
# 465532 -0.0
# 468325 -0.0
# 468295 -0.0
# 468296 -0.0
# 468297 -0.0
#         Module                                  GO_term GO_type  -log10padj
# 463801  25      collagen type VI trimer                  CC     -0.0
# 464951  25      ATF4-CREB1 transcription factor complex  CC     -0.0
# 464962  25      smooth endoplasmic reticulum             CC     -0.0
# 464961  25      nuclear pericentric heterochromatin      CC     -0.0
# 464960  25      nuclear exosome (RNase complex)          CC     -0.0
#         Module                                                   GO_term  \
# 451625  25      cellular response to menadione
# 459746  25      positive regulation of skeletal muscle fiber development
# 459737  25      aortic valve morphogenesis
# 459738  25      feeding behavior
# 459739  25      negative regulation of steroid biosynthetic process
#
#        GO_type  -log10padj
# 451625  BP     -0.0
# 459746  BP     -0.0
# 459737  BP     -0.0
# 459738  BP     -0.0
# 459739  BP     -0.0

# %%
for module in sig_modules:
    with pd.option_context('display.max_rows', 150, 'display.max_columns', 10, 'display.max_colwidth', -1):
        print(module)
        
#         display(sig_dfs[module][:10])
        
        display(sig_dfs[module][sig_dfs[module]['GO_type'] == 'MF'][:5])
        display(sig_dfs[module][sig_dfs[module]['GO_type'] == 'CC'][:5])
        display(sig_dfs[module][sig_dfs[module]['GO_type'] == 'BP'][:5])
# Out:
# 1
#       GO_type                                   GO_term  -log10padj
# 31972  MF      double-stranded RNA binding               8.759528
# 31973  MF      2'-5'-oligoadenylate synthetase activity  3.795217
# 31974  MF      protein binding                           2.981252
# 31975  MF      single-stranded RNA binding               2.981252
# 31976  MF      RNA binding                               2.981252
#       GO_type    GO_term  -log10padj
# 30241  CC      cytoplasm  7.340870
# 30242  CC      cytosol    7.340870
# 30243  CC      nucleus    2.498341
#       GO_type                                          GO_term  -log10padj
# 18065  BP      defense response to virus                        49.350886
# 18066  BP      response to virus                                29.348444
# 18067  BP      type I interferon signaling pathway              28.632232
# 18068  BP      negative regulation of viral genome replication  21.588635
# 18069  BP      innate immune response                           14.457008
# 2
#       GO_type  \
# 50037  MF
# 50038  MF
# 50039  MF
#
#                                                                      GO_term  \
# 50037  DNA-binding transcription factor activity, RNA polymerase II-specific
# 50038  glucocorticoid receptor binding
# 50039  N-box binding
#
#        -log10padj
# 50037  2.944044
# 50038  2.449056
# 50039  2.449056
#       GO_type            GO_term  -log10padj
# 48306  CC      nuclear chromatin  2.7017
# Empty DataFrame
# Columns: [GO_type, GO_term, -log10padj]
# Index: []
# 3
#       GO_type                                     GO_term  -log10padj
# 68102  MF      complement component C5a receptor activity  1.65049
#       GO_type          GO_term  -log10padj
# 66371  CC      plasma membrane  3.674337
#       GO_type                                           GO_term  -log10padj
# 54195  BP      neutrophil degranulation                          1.741061
# 54196  BP      complement component C5a signaling pathway        1.597115
# 54197  BP      positive regulation of ERK1 and ERK2 cascade      1.597115
# 54198  BP      phagocytosis                                      1.597115
# 54199  BP      negative regulation of metallopeptidase activity  1.406370
# 4
#       GO_type             GO_term  -log10padj
# 86167  MF      chemokine activity  1.476293
#       GO_type               GO_term  -log10padj
# 84436  CC      extracellular region  2.244004
# 84437  CC      extracellular space   2.244004
#       GO_type                                  GO_term  -log10padj
# 72260  BP      leukocyte chemotaxis                     2.021166
# 72261  BP      cellular response to lipopolysaccharide  1.322247
# 5
#        GO_type                                 GO_term  -log10padj
# 104232  MF      RNA binding                             6.832952
# 104233  MF      protein binding                         6.455447
# 104234  MF      snoRNA binding                          1.377837
# 104235  MF      translation initiation factor activity  1.359956
#        GO_type                 GO_term  -log10padj
# 102501  CC      nucleolus               5.723267
# 102502  CC      box C/D snoRNP complex  3.017337
# 102503  CC      membrane                2.663351
# 102504  CC      cytoplasm               1.687171
# 102505  CC      fibrillar center        1.341039
#       GO_type                              GO_term  -log10padj
# 90325  BP      rRNA processing                      2.131635
# 90326  BP      cytokine-mediated signaling pathway  2.131635
# 11
#        GO_type  \
# 212622  MF
# 212623  MF
#
#                                                                          GO_term  \
# 212622  DNA-binding transcription activator activity, RNA polymerase II-specific
# 212623  protein heterodimerization activity
#
#         -log10padj
# 212622  1.324642
# 212623  1.307801
#        GO_type                            GO_term  -log10padj
# 210891  CC      transcription factor AP-1 complex  1.812115
#        GO_type                                                        GO_term  \
# 198715  BP      response to cAMP
# 198716  BP      cellular response to hormone stimulus
# 198717  BP      positive regulation of transcription by RNA polymerase II
# 198718  BP      regulation of DNA-binding transcription factor activity
# 198719  BP      cellular response to corticotropin-releasing hormone stimulus
#
#         -log10padj
# 198715  4.597448
# 198716  2.784038
# 198717  1.778232
# 198718  1.778232
# 198719  1.442361
# 14
# Empty DataFrame
# Columns: [GO_type, GO_term, -log10padj]
# Index: []
#        GO_type                           GO_term  -log10padj
# 265086  CC      plasma membrane                   4.311191
# 265087  CC      cell                              3.803663
# 265088  CC      extracellular space               3.072537
# 265089  CC      tertiary granule membrane         2.830405
# 265090  CC      external side of plasma membrane  1.997753
#        GO_type                              GO_term  -log10padj
# 252910  BP      immune response                      5.654642
# 252911  BP      neutrophil degranulation             4.765432
# 252912  BP      inflammatory response                2.119782
# 252913  BP      chemotaxis                           2.119782
# 252914  BP      positive regulation of angiogenesis  2.038574
# 15
#        GO_type  \
# 284882  MF
# 284883  MF
# 284884  MF
# 284885  MF
# 284886  MF
#
#                                                                   GO_term  \
# 284882  ATPase-coupled peptide transmembrane transporter activity
# 284883  ATPase-coupled peptide antigen transmembrane transporter activity
# 284884  TAP1 binding
# 284885  kinase inhibitor activity
# 284886  CXCR3 chemokine receptor binding
#
#         -log10padj
# 284882  1.530475
# 284883  1.530475
# 284884  1.406756
# 284885  1.406756
# 284886  1.406756
#        GO_type                               GO_term  -log10padj
# 283151  CC      TAP complex                           2.086544
# 283152  CC      cytoplasmic vesicle                   1.806449
# 283153  CC      spermatoproteasome complex            1.611861
# 283154  CC      symbiont-containing vacuole membrane  1.611861
# 283155  CC      MHC class I peptide loading complex   1.611861
#        GO_type  \
# 270975  BP
# 270976  BP
# 270977  BP
# 270978  BP
# 270979  BP
#
#                                                                                                 GO_term  \
# 270975  tumor necrosis factor-mediated signaling pathway
# 270976  antigen processing and presentation of exogenous peptide antigen via MHC class I, TAP-dependent
# 270977  interleukin-27-mediated signaling pathway
# 270978  cellular response to interferon-gamma
# 270979  regulation of interferon-gamma-mediated signaling pathway
#
#         -log10padj
# 270975  2.636199
# 270976  2.533520
# 270977  2.181258
# 270978  2.180693
# 270979  2.165564
# 16
# Empty DataFrame
# Columns: [GO_type, GO_term, -log10padj]
# Index: []
# Empty DataFrame
# Columns: [GO_type, GO_term, -log10padj]
# Index: []
#        GO_type                           GO_term  -log10padj
# 289040  BP      cellular response to cadmium ion  2.882735
# 289041  BP      detoxification of copper ion      2.426428
# 289042  BP      negative regulation of growth     2.332187
# 289043  BP      cellular response to zinc ion     2.103906
# 289044  BP      cellular response to copper ion   1.974796
# 18
# Empty DataFrame
# Columns: [GO_type, GO_term, -log10padj]
# Index: []
# Empty DataFrame
# Columns: [GO_type, GO_term, -log10padj]
# Index: []
#        GO_type                                          GO_term  -log10padj
# 325170  BP      defense response to virus                        5.124661
# 325171  BP      toll-like receptor 9 signaling pathway           3.039414
# 325172  BP      negative regulation of viral genome replication  3.039414
# 325173  BP      toll-like receptor 7 signaling pathway           3.021206
# 325174  BP      response to interferon-gamma                     2.703009
# 20
#        GO_type                                 GO_term  -log10padj
# 375207  MF      cytokine activity                       4.732406
# 375208  MF      tumor necrosis factor receptor binding  2.853638
# 375209  MF      identical protein binding               1.485980
# 375210  MF      CCR chemokine receptor binding          1.411345
# 375211  MF      CCR1 chemokine receptor binding         1.387912
#        GO_type                           GO_term  -log10padj
# 373476  CC      extracellular space               1.729856
# 373477  CC      external side of plasma membrane  1.486180
#        GO_type  \
# 361300  BP
# 361301  BP
# 361302  BP
# 361303  BP
# 361304  BP
#
#                                                                GO_term  \
# 361300  cytokine-mediated signaling pathway
# 361301  cellular response to interleukin-1
# 361302  positive regulation of nitric oxide biosynthetic process
# 361303  apoptotic process
# 361304  positive regulation of membrane protein ectodomain proteolysis
#
#         -log10padj
# 361300  3.942704
# 361301  2.199087
# 361302  2.174694
# 361303  2.174694
# 361304  2.174694
# 22
#        GO_type                    GO_term  -log10padj
# 411337  MF      RNA binding                23.360767
# 411338  MF      unfolded protein binding   9.023433
# 411339  MF      ATP binding                6.002298
# 411340  MF      protein binding            5.340880
# 411341  MF      protein folding chaperone  4.664671
#        GO_type                               GO_term  -log10padj
# 409606  CC      nucleolus                             10.241232
# 409607  CC      membrane                              6.519920
# 409608  CC      preribosome, large subunit precursor  5.124596
# 409609  CC      extracellular exosome                 3.582000
# 409610  CC      cytoplasm                             3.125474
#        GO_type                                                    GO_term  \
# 397430  BP      rRNA processing
# 397431  BP      ribosomal large subunit biogenesis
# 397432  BP      protein stabilization
# 397433  BP      positive regulation of protein localization to Cajal body
# 397434  BP      response to unfolded protein
#
#         -log10padj
# 397430  6.040821
# 397431  5.427427
# 397432  4.238683
# 397433  4.238683
# 397434  4.227316
# 28
# Empty DataFrame
# Columns: [GO_type, GO_term, -log10padj]
# Index: []
# Empty DataFrame
# Columns: [GO_type, GO_term, -log10padj]
# Index: []
#        GO_type  \
# 505820  BP
# 505821  BP
# 505822  BP
# 505823  BP
# 505824  BP
#
#                                                                      GO_term  \
# 505820  inflammatory response
# 505821  cytokine-mediated signaling pathway
# 505822  positive regulation of vascular endothelial growth factor production
# 505823  positive regulation of neuroinflammatory response
# 505824  positive regulation of smooth muscle cell proliferation
#
#         -log10padj
# 505820  5.556012
# 505821  5.345955
# 505822  3.888010
# 505823  3.795166
# 505824  2.803916
# 29
#        GO_type                               GO_term  -log10padj
# 537792  MF      peptide antigen binding               3.691320
# 537793  MF      MHC class II receptor activity        2.829028
# 537794  MF      MHC class II protein complex binding  2.339478
#        GO_type  \
# 536061  CC
# 536062  CC
# 536063  CC
# 536064  CC
# 536065  CC
#
#                                                                      GO_term  \
# 536061  MHC class II protein complex
# 536062  clathrin-coated endocytic vesicle membrane
# 536063  integral component of lumenal side of endoplasmic reticulum membrane
# 536064  plasma membrane
# 536065  transport vesicle membrane
#
#         -log10padj
# 536061  9.415346
# 536062  5.466313
# 536063  4.135141
# 536064  4.067765
# 536065  3.420023
#        GO_type  \
# 523885  BP
# 523886  BP
# 523887  BP
# 523888  BP
# 523889  BP
#
#                                                                                   GO_term  \
# 523885  peptide antigen assembly with MHC class II protein complex
# 523886  antigen processing and presentation of exogenous peptide antigen via MHC class II
# 523887  interferon-gamma-mediated signaling pathway
# 523888  adaptive immune response
# 523889  immune response
#
#         -log10padj
# 523885  4.136632
# 523886  3.798667
# 523887  3.173135
# 523888  2.633257
# 523889  1.313907

# %%
for module in sig_modules:
    df = sig_dfs[module][sig_dfs[module]['GO_term'].str.contains('lipopolysaccharide')]
    if len(df) != 0:
        print(module)
        print(df)
        print('')
# Out:
# 4
#       GO_type                                  GO_term  -log10padj
# 72261      BP  cellular response to lipopolysaccharide    1.322247
#
# 11
#        GO_type                         GO_term  -log10padj
# 198720      BP  response to lipopolysaccharide    1.320502
#
# 28
#        GO_type                                        GO_term  -log10padj
# 505825      BP        cellular response to lipopolysaccharide    2.589933
# 505831      BP  lipopolysaccharide-mediated signaling pathway    2.048618

# %% [markdown]
# To export to csv to open in Excel for easy labeling:

# %%
dfs = list()
for sig_module in sig_modules:
    dfs.append(results_df[(results_df['-log10padj'] > -np.log10(0.05)) &
                          (results_df['Module'] == sig_module)
                         ][['Module', 'GO_type', 'GO_term', '-log10padj']].sort_values(['GO_type', '-log10padj'], ascending=False))

# %%
# pd.concat(dfs).to_csv(prefix + 'kmeans.modules/kmeans.n30.sig.modules.GO.csv')

# %% [markdown]
# ### Label the Significant Modules

# %%
sig_modules
# Out:
# [1, 2, 3, 4, 5, 11, 14, 15, 16, 18, 20, 22, 28, 29]

# %%
sig_module_labels = {
    1: 'viral response & interferon activity',
    2: 'glucocorticoid stress response',
    3: 'complement cascade',
    4: 'chemotaxis',
    5: 'protein production',
    11: 'cAMP response',
    14: 'degranulation',
    15: 'peptide transporter & interferon activity',
    16: 'metal ion response',
    18: 'TLR signaling',
    20: 'cytokine activity',
    22: 'protein production',
    28: 'Inflammation & T helper activity', 
    29: 'MHC II activity',
}

# %%
len(sig_modules)
# Out:
# 14

# %%
cond_long_colors = dict(zip([k for k, v in cond_dict.items()], [cond_colors[v] for k, v in cond_dict.items()]))

# %% [markdown]
# I realized that plotting mean expression of the genes in each module may reduce the signal for genes that are part of a module (and contribute to the module's signifance) but that are downregulated. Therefore, going to plot the mean log fold change (from control) of genes within the module, and just won't plot control (since it will be 1).

# %%
# specific_counts = specific_counts.abs()
# specific_counts = specific_counts.reset_index()

# specific_counts['TIME'] = specific_counts['TIME'].astype(int)

# specific_counts.mean(axis=0,level=['TIME', 'STIM']).head()

# specific_counts.sort_values(['STIM','TIME','IND'])

# %%
fig, ax = plt.subplots(3, 5, figsize=(30,18))
for sig_module, ax in zip(sig_modules, np.ravel(ax)):
#     gene_union = np.unique(np.concatenate([de_genes[stim][i] for i in hours]))
#     specific_counts = counts['norm'][gene_union]

    specific_counts = counts['norm_lfc'][main_modules_genes[sig_module]]#.abs()
    means = specific_counts.mean(1)

    means.rename('Mean Log Fold Change (from Control)', inplace=True);

    tidy_means = means.reset_index()
    tidy_means['TIME'] = tidy_means['TIME'].astype(int)
    # tidy_means = tidy_means[(tidy_means['STIM'] == stim) | (tidy_means['STIM'] == 'Control')]

    sns.lineplot(x="TIME",y='Mean Log Fold Change (from Control)',data=tidy_means, hue='STIM', err_style="band", ci="sd", ax=ax, palette=cond_long_colors);
    ax.grid(False)
#     ax.set_yscale('log')
    ax.set_ylabel(None)
    ymax = ax.get_ylim()[1]
#     ax.set_ylim((0,ymax))
    ax.set_title(str(sig_module_labels[sig_module]) + ' (' + str(sig_module) + ')')
    ax.get_legend().remove()
    ax.plot([3, 12], [0, 0], linestyle='--', color='r', linewidth=1)
plt.tight_layout()

# %%
fig, ax = plt.subplots(2, 2, figsize=(10,10))
for sig_module, ax in zip([1, 3, 18, 29], np.ravel(ax)):
#     gene_union = np.unique(np.concatenate([de_genes[stim][i] for i in hours]))
#     specific_counts = counts['norm'][gene_union]

    specific_counts = counts['norm_lfc'][main_modules_genes[sig_module]]#.abs()
    means = specific_counts.mean(1)

    means.rename('Mean Log Fold Change (from Control)', inplace=True);

    tidy_means = means.reset_index()
    tidy_means['TIME'] = tidy_means['TIME'].astype(int)
    # tidy_means = tidy_means[(tidy_means['STIM'] == stim) | (tidy_means['STIM'] == 'Control')]

    sns.lineplot(x="TIME",y='Mean Log Fold Change (from Control)',data=tidy_means, hue='STIM', err_style="band", ci="sd", ax=ax, palette=cond_long_colors);
    ax.grid(False)
#     ax.set_yscale('log')
    ax.set_ylabel(None)
    ax.set_xlabel(None)
    ymax = ax.get_ylim()[1]
#     ax.set_ylim((0,ymax))
    ax.set_title(str(sig_module_labels[sig_module]) + ' (' + str(sig_module) + ')')
    ax.get_legend().remove()
    ax.plot([3, 12], [0, 0], linestyle='--', color='r', linewidth=1)
plt.tight_layout()

# %% [markdown]
# ## DE Gene Expression Plots

# %% [markdown]
# CAUTION: All of the following cells (until the Figures section) uses the `de_genes` object that was created towards the top of this notebook. I made two separate versions, and more can be made using different thresholds for log fold change, significance level, and **_most-importantly_**, whether or not to plot only upregulated genes or both upregulated and downregulated genes. However, **_results will change_** depending on which version of the object is currently loaded, so going back to those cells and re-running them before running the next cells is recommended.
#
# Plotting the mean expression of the genes over time.

# %% [markdown]
# First, build a color dictionary to keep the colors consistent between all the plots I will generate. I'm going to use the colors from Scanpy to make it consistent.

# %%
counts.keys()
# Out:
# dict_keys(['raw', 'meta', 'norm'])

# %%
data_type = 'norm'

# %%
stim_values = counts[data_type].index.get_level_values('STIM').unique()
colors = sc.pl.palettes.default_20[:len(stim_values)]

# %%
stim_values
# Out:
# Index(['None', 'Control', 'IFNB', 'IFNG', 'PMAI', 'R848', 'TNFa'], dtype='object', name='STIM')

# %%
list(zip(range(len(colors)), colors))
# Out:
# [(0, '#1f77b4'),
#  (1, '#ff7f0e'),
#  (2, '#279e68'),
#  (3, '#d62728'),
#  (4, '#aa40fc'),
#  (5, '#8c564b'),
#  (6, '#e377c2')]

# %%
stim_values
# Out:
# Index(['None', 'Control', 'IFNB', 'IFNG', 'PMAI', 'R848', 'TNFa'], dtype='object', name='STIM')

# %%
color_dict = dict(zip(['None', 'Control', 'IFNB', 'IFNG', 'PMAI', 'R848', 'TNFa'],
                       ['#1f77b4', '#d62728','#279e68','#aa40fc','#8c564b','#e377c2','#ff7f0e'])
                 )

# %% [markdown]
# **Mean expression of *time-point specific* DE genes at each time point, relative to control**
#
# To do this using `seaborn`, I'd like to build a `pd.Series` with a multiIndex), then fill it, and then flatten in with `.reset_index()` just before plotting.

# %%
idx = list(it.product(stims,['stim','control'],inds, [int(i) for i in hours]))

# %%
de_hour = pd.Series(index=pd.MultiIndex.from_tuples(idx,names=['DEGs_FOR', 'SAMPLE', 'IND', 'TIME']), name='Mean Expression')
# Out:
# /home/ssm-user/anaconda3/envs/codec/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# Here's a doozy, filling in my Series with many nested for loops.

# %%
for stim in tqdm(stims):
    for label in ['stim', 'control']:
        for ind in inds:
            for hour in hours:
                if label == 'stim':
                    sample = stim
                else:
                    sample = 'Control'
                de_hour.loc[(stim, label, ind, int(hour))] = counts[data_type].loc[(counts[data_type].index.get_level_values("IND") == ind) & 
                                                                                   (counts[data_type].index.get_level_values("STIM") == sample) & 
                                                                                   (counts[data_type].index.get_level_values("TIME") == hour),
                                                                                   de_genes[stim][hour]].values.mean()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))

# %%
fig, ax = plt.subplots(1,5,figsize=(25,5))
for stim, ax in zip(stims,ax):
    tidy_de_hour = de_hour.reset_index()
    tidy_de_hour = tidy_de_hour[tidy_de_hour['DEGs_FOR'] == stim]
    sns.lineplot(x="TIME",y='Mean Expression',data=tidy_de_hour, hue='SAMPLE', err_style="bars", ci="sd", ax=ax, palette=[color_dict[stim],color_dict['Control']])
    ax.set_title(stim)
    ax.get_legend().remove()
plt.tight_layout()

# %% [markdown]
# **Mean expression of *common DE genes* at each time point, relative to control**
#
# Here I choose to either use the union or intersection of genes across all time points. Comment in/out the relative lines of code to get those values.

# %%
fig, ax = plt.subplots(1, 5, figsize=(28,5))
for stim, ax in zip(stims, np.ravel(ax)):
#     gene_union = np.unique(np.concatenate([de_genes[stim][i] for i in hours]))
#     specific_counts = counts['norm'][gene_union]

    gene_int = reduce(np.intersect1d, [de_genes[stim][i] for i in hours])
    specific_counts = counts[data_type][gene_int]

    means = specific_counts.mean(1)

    means.rename('Mean Expression', inplace=True);

    tidy_means = means.reset_index()
    tidy_means['TIME'] = tidy_means['TIME'].astype(int)
    # tidy_means = tidy_means[(tidy_means['STIM'] == stim) | (tidy_means['STIM'] == 'Control')]

    sns.lineplot(x="TIME",y='Mean Expression',data=tidy_means, hue='STIM', err_style="bars", ci="sd", ax=ax, palette=color_dict);
    ax.set_title(stim + " " + "(" + str(specific_counts.shape[1]) + ")")
    ax.get_legend().remove()
plt.tight_layout()

# %% [markdown]
# **Mean expression of *PMAI-specific genes* at each time point, but applied across all time points, relative to control**
#
# I noticed that for PMAI in particular, the genes turned on at 3 hours are turned off at 12 hours, and vice versa. This is not really observed in any of the other stimulation conditions.

# %%
fig, ax = plt.subplots(1, 4, figsize=(20,5))
stim = 'PMAI'
for hour, ax in zip(hours, np.ravel(ax)):

    specific_counts = counts[data_type][de_genes[stim][hour]]
    means = specific_counts.mean(1)

    means.rename('Mean Expression', inplace=True);

    tidy_means = means.reset_index()
    tidy_means['TIME'] = tidy_means['TIME'].astype(int)
    tidy_means = tidy_means[(tidy_means['STIM'] == stim) | (tidy_means['STIM'] == 'Control') | (tidy_means['STIM'] == 'None')]

    sns.lineplot(x="TIME",y='Mean Expression',data=tidy_means, hue='STIM', err_style="bars", ci="sd", ax=ax, palette=color_dict);
    ax.set_title(hour + "HR DE Genes")
    ax.get_legend().remove()
plt.tight_layout()

# %%
fig, ax = plt.subplots(1, 4, figsize=(20,5))
stim = 'TNFa'
for hour, ax in zip(hours, np.ravel(ax)):

    specific_counts = counts[data_type][de_genes[stim][hour]]
    means = specific_counts.mean(1)

    means.rename('Mean Expression', inplace=True);

    tidy_means = means.reset_index()
    tidy_means['TIME'] = tidy_means['TIME'].astype(int)
    tidy_means = tidy_means[(tidy_means['STIM'] == stim) | (tidy_means['STIM'] == 'Control') | (tidy_means['STIM'] == 'None')]

    sns.lineplot(x="TIME",y='Mean Expression',data=tidy_means, hue='STIM', err_style="bars", ci="sd", ax=ax, palette=color_dict);
    ax.set_title(hour + "HR DE Genes")
    ax.get_legend().remove()
plt.tight_layout()

# %% [markdown]
# ### Correlation of Expression of All Genes for Each Stim Relative to Control
# I noticed the TNFa response is modest, and the expression values seem to highly correlate with control. Trying to quantify and visualize that here.

# %% [markdown]
# Build a list of the pearson R values between each stim and the common control, for all **12** individual- and time-matched samples.

# %%
pearsons = list()
for stim in stims:
    df = counts[data_type][(counts[data_type].index.get_level_values("STIM") == stim) | (counts[data_type].index.get_level_values("STIM") == 'Control')]
    myiter = df.iterrows()
    for _ in range(12):
        x = next(myiter)
        y = next(myiter)
        
        arr = np.array(list(zip(x[1].values, y[1].values)))
        arr = arr[arr.sum(1) != 0]
        
        pearsons.append([stim,np.corrcoef(arr, rowvar=False)[0,1]])

# %%
pearsons = pd.DataFrame(pearsons,columns = ['stim','r'])

# %%
ax = sns.stripplot(data=pearsons,x='stim',y='r',palette=color_dict,);
ax = sns.barplot(data=pearsons,x='stim',y='r',palette=color_dict, alpha=0.5, ax=ax);
plt.ylim(0.6,1);
plt.ylabel('Mean correlation coefficient');

# %% [markdown]
# ### Gene Ontology Analysis

# %%
obo_fname = download_go_basic_obo(prefix + "go-basic.obo")
fin_gene2go = download_ncbi_associations(prefix + 'gene2go')
# Out:
#   EXISTS: /data/codec/bulk.jan20/go-basic.obo
#   EXISTS: /data/codec/bulk.jan20/gene2go

# %%
obodag = GODag(prefix + "go-basic.obo")
# Out:
# /data/codec/bulk.jan20/go-basic.obo: fmt(1.2) rel(2020-02-21) 47,245 GO Terms

# %%
# Read NCBI's gene2go. Store annotations in a list of named tuples
objanno = Gene2GoReader(fin_gene2go, taxids=[9606])

# Get namespace2association where:
#    namespace is:
#        BP: biological_process               
#        MF: molecular_function
#        CC: cellular_component
#    assocation is a dict:
#        key: NCBI GeneID
#        value: A set of GO IDs associated with that gene
ns2assoc = objanno.get_ns2assc()

for nspc, id2gos in ns2assoc.items():
    print("{NS} {N:,} annotated human genes".format(NS=nspc, N=len(id2gos)))
# Out:
# HMS:0:00:04.595826 323,107 annotations, 19,649 genes, 18,246 GOs, 1 taxids READ: /data/codec/bulk.jan20/gene2go
# CC 18,648 annotated human genes
# BP 17,541 annotated human genes
# MF 17,384 annotated human genes

# %%
gene_ids = list(GeneID2nt_hum.keys())
symbol2geneid = dict(zip([GeneID2nt_hum[i].Symbol for i in gene_ids], [i for i in gene_ids]))

# %% [markdown]
# Selecting a few samples that look like they may reveal the most interesting biology.

# %%
stim_hours = [('IFNG','9'), ('IFNB', '9'), ('PMAI', '3'), ('PMAI', '12'), ('R848', '6'), ('TNFa','3')]

# %% [markdown]
# Next cell produces a lot of output, recommend collapsing it in notebook.

# %%
results = list()
for stim, hour in tqdm(stim_hours):
    ids = list()
    for i in de_genes[stim][hour]:
        try:
            ids.append(symbol2geneid[i])
        except:
            continue
    print(len(ids)/len(de_genes[stim][hour]))
    
    goeaobj = GOEnrichmentStudyNS(
            GeneID2nt_hum.keys(), # List of human protein-coding genes
            ns2assoc, # geneid/GO associations
            obodag, # Ontologies
            propagate_counts = False,
            alpha = 0.05, # default significance cut-off
            methods = ['fdr_bh']) # defult multipletest correction method
    
    goea_results_all = goeaobj.run_study(ids)
    for i in goea_results_all:
        results.append([stim + ", " + hour, i.name, i.NS, -np.log10(i.p_fdr_bh)])
# Out:
# HBox(children=(FloatProgress(value=0.0, max=6.0), HTML(value='')))
# 0.9250936329588015
#
# Load BP Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,711 of 20,913 population items found in association
#
# Load CC Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  85% 17,755 of 20,913 population items found in association
#
# Load MF Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,699 of 20,913 population items found in association
#
# Run BP Gene Ontology Analysis: current study set of 247 IDs ... 96%    238 of    247 study items found in association
# 100%    247 of    247 study items found in population(20913)
# Calculating 12,176 uncorrected p-values using fisher_scipy_stats
#   12,176 GO terms are associated with 16,711 of 20,913 population items
#    1,748 GO terms are associated with    238 of    247 study items
#   METHOD fdr_bh:
#       57 GO terms found significant (< 0.05=alpha) ( 57 enriched +   0 purified): statsmodels fdr_bh
#      136 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 247 IDs ... 97%    239 of    247 study items found in association
# 100%    247 of    247 study items found in population(20913)
# Calculating 1,731 uncorrected p-values using fisher_scipy_stats
#    1,731 GO terms are associated with 17,755 of 20,913 population items
#      257 GO terms are associated with    239 of    247 study items
#   METHOD fdr_bh:
#       28 GO terms found significant (< 0.05=alpha) ( 28 enriched +   0 purified): statsmodels fdr_bh
#      201 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 247 IDs ... 96%    237 of    247 study items found in association
# 100%    247 of    247 study items found in population(20913)
# Calculating 4,158 uncorrected p-values using fisher_scipy_stats
#    4,158 GO terms are associated with 16,699 of 20,913 population items
#      436 GO terms are associated with    237 of    247 study items
#   METHOD fdr_bh:
#        8 GO terms found significant (< 0.05=alpha) (  8 enriched +   0 purified): statsmodels fdr_bh
#      175 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# 0.9180327868852459
#
# Load BP Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,711 of 20,913 population items found in association
#
# Load CC Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  85% 17,755 of 20,913 population items found in association
#
# Load MF Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,699 of 20,913 population items found in association
#
# Run BP Gene Ontology Analysis: current study set of 280 IDs ... 91%    256 of    280 study items found in association
# 100%    280 of    280 study items found in population(20913)
# Calculating 12,176 uncorrected p-values using fisher_scipy_stats
#   12,176 GO terms are associated with 16,711 of 20,913 population items
#    1,492 GO terms are associated with    256 of    280 study items
#   METHOD fdr_bh:
#       34 GO terms found significant (< 0.05=alpha) ( 34 enriched +   0 purified): statsmodels fdr_bh
#      129 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 280 IDs ... 94%    264 of    280 study items found in association
# 100%    280 of    280 study items found in population(20913)
# Calculating 1,731 uncorrected p-values using fisher_scipy_stats
#    1,731 GO terms are associated with 17,755 of 20,913 population items
#      266 GO terms are associated with    264 of    280 study items
#   METHOD fdr_bh:
#        3 GO terms found significant (< 0.05=alpha) (  3 enriched +   0 purified): statsmodels fdr_bh
#      137 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 280 IDs ... 93%    261 of    280 study items found in association
# 100%    280 of    280 study items found in population(20913)
# Calculating 4,158 uncorrected p-values using fisher_scipy_stats
#    4,158 GO terms are associated with 16,699 of 20,913 population items
#      429 GO terms are associated with    261 of    280 study items
#   METHOD fdr_bh:
#        9 GO terms found significant (< 0.05=alpha) (  9 enriched +   0 purified): statsmodels fdr_bh
#      180 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# 0.5934579439252337
#
# Load BP Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,711 of 20,913 population items found in association
#
# Load CC Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  85% 17,755 of 20,913 population items found in association
#
# Load MF Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,699 of 20,913 population items found in association
#
# Run BP Gene Ontology Analysis: current study set of 254 IDs ... 94%    239 of    254 study items found in association
# 100%    254 of    254 study items found in population(20913)
# Calculating 12,176 uncorrected p-values using fisher_scipy_stats
#   12,176 GO terms are associated with 16,711 of 20,913 population items
#    1,930 GO terms are associated with    239 of    254 study items
#   METHOD fdr_bh:
#       71 GO terms found significant (< 0.05=alpha) ( 71 enriched +   0 purified): statsmodels fdr_bh
#      148 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 254 IDs ... 96%    245 of    254 study items found in association
# 100%    254 of    254 study items found in population(20913)
# Calculating 1,731 uncorrected p-values using fisher_scipy_stats
#    1,731 GO terms are associated with 17,755 of 20,913 population items
#      231 GO terms are associated with    245 of    254 study items
#   METHOD fdr_bh:
#        4 GO terms found significant (< 0.05=alpha) (  4 enriched +   0 purified): statsmodels fdr_bh
#      113 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 254 IDs ... 92%    234 of    254 study items found in association
# 100%    254 of    254 study items found in population(20913)
# Calculating 4,158 uncorrected p-values using fisher_scipy_stats
#    4,158 GO terms are associated with 16,699 of 20,913 population items
#      384 GO terms are associated with    234 of    254 study items
#   METHOD fdr_bh:
#       16 GO terms found significant (< 0.05=alpha) ( 16 enriched +   0 purified): statsmodels fdr_bh
#      176 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# 0.8555798687089715
#
# Load BP Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,711 of 20,913 population items found in association
#
# Load CC Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  85% 17,755 of 20,913 population items found in association
#
# Load MF Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,699 of 20,913 population items found in association
#
# Run BP Gene Ontology Analysis: current study set of 391 IDs ... 95%    373 of    391 study items found in association
# 100%    391 of    391 study items found in population(20913)
# Calculating 12,176 uncorrected p-values using fisher_scipy_stats
#   12,176 GO terms are associated with 16,711 of 20,913 population items
#    2,316 GO terms are associated with    373 of    391 study items
#   METHOD fdr_bh:
#       49 GO terms found significant (< 0.05=alpha) ( 49 enriched +   0 purified): statsmodels fdr_bh
#      148 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 391 IDs ... 96%    377 of    391 study items found in association
# 100%    391 of    391 study items found in population(20913)
# Calculating 1,731 uncorrected p-values using fisher_scipy_stats
#    1,731 GO terms are associated with 17,755 of 20,913 population items
#      354 GO terms are associated with    377 of    391 study items
#   METHOD fdr_bh:
#        8 GO terms found significant (< 0.05=alpha) (  8 enriched +   0 purified): statsmodels fdr_bh
#      151 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 391 IDs ... 92%    358 of    391 study items found in association
# 100%    391 of    391 study items found in population(20913)
# Calculating 4,158 uncorrected p-values using fisher_scipy_stats
#    4,158 GO terms are associated with 16,699 of 20,913 population items
#      608 GO terms are associated with    358 of    391 study items
#   METHOD fdr_bh:
#        5 GO terms found significant (< 0.05=alpha) (  5 enriched +   0 purified): statsmodels fdr_bh
#      241 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# 0.7985611510791367
#
# Load BP Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,711 of 20,913 population items found in association
#
# Load CC Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  85% 17,755 of 20,913 population items found in association
#
# Load MF Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,699 of 20,913 population items found in association
#
# Run BP Gene Ontology Analysis: current study set of 333 IDs ... 95%    318 of    333 study items found in association
# 100%    333 of    333 study items found in population(20913)
# Calculating 12,176 uncorrected p-values using fisher_scipy_stats
#   12,176 GO terms are associated with 16,711 of 20,913 population items
#    2,165 GO terms are associated with    318 of    333 study items
#   METHOD fdr_bh:
#      135 GO terms found significant (< 0.05=alpha) (135 enriched +   0 purified): statsmodels fdr_bh
#      226 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 333 IDs ... 97%    323 of    333 study items found in association
# 100%    333 of    333 study items found in population(20913)
# Calculating 1,731 uncorrected p-values using fisher_scipy_stats
#    1,731 GO terms are associated with 17,755 of 20,913 population items
#      268 GO terms are associated with    323 of    333 study items
#   METHOD fdr_bh:
#        9 GO terms found significant (< 0.05=alpha) (  9 enriched +   0 purified): statsmodels fdr_bh
#      213 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 333 IDs ... 95%    316 of    333 study items found in association
# 100%    333 of    333 study items found in population(20913)
# Calculating 4,158 uncorrected p-values using fisher_scipy_stats
#    4,158 GO terms are associated with 16,699 of 20,913 population items
#      532 GO terms are associated with    316 of    333 study items
#   METHOD fdr_bh:
#       17 GO terms found significant (< 0.05=alpha) ( 17 enriched +   0 purified): statsmodels fdr_bh
#      241 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# 0.9765625
#
# Load BP Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,711 of 20,913 population items found in association
#
# Load CC Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  85% 17,755 of 20,913 population items found in association
#
# Load MF Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  80% 16,699 of 20,913 population items found in association
#
# Run BP Gene Ontology Analysis: current study set of 125 IDs ... 95%    119 of    125 study items found in association
# 100%    125 of    125 study items found in population(20913)
# Calculating 12,176 uncorrected p-values using fisher_scipy_stats
#   12,176 GO terms are associated with 16,711 of 20,913 population items
#    1,292 GO terms are associated with    119 of    125 study items
#   METHOD fdr_bh:
#       49 GO terms found significant (< 0.05=alpha) ( 49 enriched +   0 purified): statsmodels fdr_bh
#       75 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 125 IDs ... 97%    121 of    125 study items found in association
# 100%    125 of    125 study items found in population(20913)
# Calculating 1,731 uncorrected p-values using fisher_scipy_stats
#    1,731 GO terms are associated with 17,755 of 20,913 population items
#      181 GO terms are associated with    121 of    125 study items
#   METHOD fdr_bh:
#        4 GO terms found significant (< 0.05=alpha) (  4 enriched +   0 purified): statsmodels fdr_bh
#       45 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 125 IDs ... 95%    119 of    125 study items found in association
# 100%    125 of    125 study items found in population(20913)
# Calculating 4,158 uncorrected p-values using fisher_scipy_stats
#    4,158 GO terms are associated with 16,699 of 20,913 population items
#      253 GO terms are associated with    119 of    125 study items
#   METHOD fdr_bh:
#        4 GO terms found significant (< 0.05=alpha) (  4 enriched +   0 purified): statsmodels fdr_bh
#       89 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)

# %%
results_df = pd.DataFrame(results, columns=['Sample','GO_term','GO_type','-log10padj'])

# %%
plt.figure(figsize=(10,4))
sns.stripplot(data=results_df,x='Sample', hue='GO_type', y='-log10padj', dodge=True, size=2);
plt.plot([-0.5,5.5],[-np.log10(0.01)]*2, linestyle='--', linewidth=1, color='r');

# %% [markdown]
# ### Print out GO Analysis Results

# %%
from IPython.display import display # need this to print out the results without truncation.

# %%
sample = 'TNFa, 3' # input whichever sample you'd like here

# %%
df = results_df[(results_df['-log10padj'] > -np.log10(0.01)) &
                (results_df['Sample'] == sample)
               ][['GO_type', 'GO_term', '-log10padj']].sort_values(['GO_type', '-log10padj'], ascending=False)
with pd.option_context('display.max_rows', 120, 'display.max_columns', 10, 'display.max_colwidth', -1):
    display(df)
# Out:
#        GO_type  \
# 104232  MF
# 104233  MF
# 104234  MF
# 102501  CC
# 90325   BP
# 90326   BP
# 90327   BP
# 90328   BP
# 90329   BP
# 90330   BP
# 90331   BP
# 90332   BP
# 90333   BP
# 90334   BP
# 90335   BP
# 90336   BP
# 90337   BP
# 90338   BP
# 90339   BP
# 90340   BP
# 90341   BP
# 90342   BP
#
#                                                                GO_term  \
# 104232  chemokine activity
# 104233  identical protein binding
# 104234  CCR chemokine receptor binding
# 102501  membrane raft
# 90325   inflammatory response
# 90326   neutrophil chemotaxis
# 90327   cytokine-mediated signaling pathway
# 90328   apoptotic process
# 90329   cellular response to lipopolysaccharide
# 90330   lipopolysaccharide-mediated signaling pathway
# 90331   cellular response to interleukin-1
# 90332   chemokine-mediated signaling pathway
# 90333   positive regulation of NF-kappaB transcription factor activity
# 90334   I-kappaB kinase/NF-kappaB signaling
# 90335   negative regulation of apoptotic process
# 90336   positive regulation of inflammatory response
# 90337   cellular response to tumor necrosis factor
# 90338   lymphocyte chemotaxis
# 90339   positive regulation of fever generation
# 90340   positive regulation of nitric oxide biosynthetic process
# 90341   signal transduction
# 90342   monocyte chemotaxis
#
#         -log10padj
# 104232  5.702485
# 104233  3.588802
# 104234  2.985992
# 102501  2.785704
# 90325   18.385375
# 90326   9.366797
# 90327   7.441759
# 90328   7.441759
# 90329   7.376679
# 90330   7.376679
# 90331   5.638472
# 90332   4.863559
# 90333   4.555953
# 90334   3.788165
# 90335   3.603943
# 90336   3.480347
# 90337   3.071490
# 90338   2.965254
# 90339   2.775345
# 90340   2.525630
# 90341   2.491447
# 90342   2.417793

# %% [markdown]
# ### Highlight Some GO Terms

# %%
highlight = ['immune response', 
             'inflammatory response', 
             'interferon-gamma-mediated signaling pathway',
             'type I interferon signaling pathway',
             'defense response to virus',
             'cytokine activity',
             'neutrophil chemotaxis',
             'innate immune response',
             'response to interferon-beta',
             'positive regulation of NF-kappaB transcription factor activity',
             'positive regulation of cell population proliferation'
            ]

# %%
results_df_no_time = results_df.copy()
results_df_no_time['Sample'] = list(map(lambda x: x[0], results_df_no_time['Sample'].str.split(', ')))

# %%
plt.figure(figsize=(4,10))
sns.barplot(data=results_df_no_time[results_df_no_time['GO_term'].isin(highlight)],
            orient="h", x="-log10padj", y='GO_term', hue='Sample', palette=color_dict);

# %% [markdown]
# ### Compare GO Results between Two PMAI Responses

# %%
pmai3 = results_df[(results_df['Sample'] == ('PMAI, 3')) & (results_df['-log10padj'] > -np.log10(0.05))]
pmai12 = results_df[(results_df['Sample'] == ('PMAI, 12')) & (results_df['-log10padj'] > -np.log10(0.05))]

# %%
pmai3_diff = np.setdiff1d(pmai3['GO_term'].values,pmai12['GO_term'].values)

# %%
pmai12_diff = np.setdiff1d(pmai12['GO_term'].values,pmai3['GO_term'].values)

# %%
with pd.option_context('display.max_rows', 120, 'display.max_columns', 10, 'display.max_colwidth', -1):
    display(pmai3[(pmai3['GO_term'].isin(pmai3_diff)) & (pmai3['GO_type'] == 'BP')].sort_values('-log10padj', ascending=False))
# Out:
#         Sample  \
# 36137  PMAI, 3
# 36139  PMAI, 3
# 36141  PMAI, 3
# 36147  PMAI, 3
# 36149  PMAI, 3
# 36151  PMAI, 3
# 36153  PMAI, 3
# 36154  PMAI, 3
# 36155  PMAI, 3
# 36156  PMAI, 3
# 36159  PMAI, 3
# 36160  PMAI, 3
# 36165  PMAI, 3
# 36166  PMAI, 3
# 36167  PMAI, 3
# 36168  PMAI, 3
# 36169  PMAI, 3
# 36170  PMAI, 3
# 36172  PMAI, 3
# 36173  PMAI, 3
# 36179  PMAI, 3
# 36181  PMAI, 3
# 36180  PMAI, 3
# 36175  PMAI, 3
# 36178  PMAI, 3
# 36176  PMAI, 3
# 36177  PMAI, 3
# 36183  PMAI, 3
# 36184  PMAI, 3
# 36185  PMAI, 3
# 36186  PMAI, 3
# 36187  PMAI, 3
# 36190  PMAI, 3
# 36189  PMAI, 3
# 36191  PMAI, 3
# 36192  PMAI, 3
# 36194  PMAI, 3
# 36196  PMAI, 3
# 36198  PMAI, 3
# 36199  PMAI, 3
# 36200  PMAI, 3
#
#                                                                           GO_term  \
# 36137  positive regulation of transcription by RNA polymerase II
# 36139  myeloid dendritic cell differentiation
# 36141  negative regulation of transcription by RNA polymerase II
# 36147  signal transduction
# 36149  positive regulation of smooth muscle cell proliferation
# 36151  activation of MAPKKK activity
# 36153  regulation of cell adhesion
# 36154  negative regulation of immune response
# 36155  skeletal muscle cell differentiation
# 36156  cellular response to corticotropin-releasing hormone stimulus
# 36159  regulation of regulatory T cell differentiation
# 36160  positive regulation of gene expression
# 36165  cellular response to extracellular stimulus
# 36166  regulation of immune response
# 36167  positive regulation of interleukin-6 production
# 36168  regulation of transcription by RNA polymerase II
# 36169  negative regulation of angiogenesis
# 36170  positive regulation of T cell proliferation
# 36172  positive regulation of transforming growth factor beta production
# 36173  cell differentiation
# 36179  positive regulation of synaptic transmission, cholinergic
# 36181  GABAergic neuron differentiation
# 36180  positive regulation of chronic inflammatory response to antigenic stimulus
# 36175  negative regulation of hormone secretion
# 36178  positive regulation of nitrogen compound metabolic process
# 36176  positive regulation of vitamin D biosynthetic process
# 36177  positive regulation of eosinophil differentiation
# 36183  fat cell differentiation
# 36184  positive regulation of T cell mediated cytotoxicity
# 36185  positive regulation of neutrophil chemotaxis
# 36186  response to cAMP
# 36187  extrinsic apoptotic signaling pathway
# 36190  positive regulation of mast cell degranulation
# 36189  positive regulation of isotype switching to IgG isotypes
# 36191  positive regulation of transcription, DNA-templated
# 36192  positive regulation of apoptotic process
# 36194  regulation of apoptotic process
# 36196  cellular response to interleukin-4
# 36198  positive regulation of chemokine biosynthetic process
# 36199  positive regulation of acute inflammatory response
# 36200  positive regulation of podosome assembly
#
#       GO_type  -log10padj
# 36137  BP      5.878226
# 36139  BP      4.218051
# 36141  BP      3.970814
# 36147  BP      2.799795
# 36149  BP      2.411710
# 36151  BP      2.268175
# 36153  BP      2.192337
# 36154  BP      2.168154
# 36155  BP      2.121338
# 36156  BP      2.121338
# 36159  BP      1.974827
# 36160  BP      1.885681
# 36165  BP      1.715887
# 36166  BP      1.684455
# 36167  BP      1.684455
# 36168  BP      1.684455
# 36169  BP      1.684455
# 36170  BP      1.626653
# 36172  BP      1.571223
# 36173  BP      1.514903
# 36179  BP      1.463356
# 36181  BP      1.463356
# 36180  BP      1.463356
# 36175  BP      1.463356
# 36178  BP      1.463356
# 36176  BP      1.463356
# 36177  BP      1.463356
# 36183  BP      1.412537
# 36184  BP      1.412537
# 36185  BP      1.412537
# 36186  BP      1.412537
# 36187  BP      1.412537
# 36190  BP      1.399922
# 36189  BP      1.399922
# 36191  BP      1.392038
# 36192  BP      1.385186
# 36194  BP      1.347031
# 36196  BP      1.331460
# 36198  BP      1.331460
# 36199  BP      1.331460
# 36200  BP      1.331460

# %%
with pd.option_context('display.max_rows', 120, 'display.max_columns', 10, 'display.max_colwidth', -1):
    display(pmai12[(pmai12['GO_term'].isin(pmai12_diff)) & (pmai12['GO_type'] == 'BP')].sort_values('-log10padj', ascending=False))
# Out:
#          Sample  \
# 54202  PMAI, 12
# 54219  PMAI, 12
# 54220  PMAI, 12
# 54222  PMAI, 12
# 54223  PMAI, 12
# 54224  PMAI, 12
# 54227  PMAI, 12
# 54228  PMAI, 12
# 54231  PMAI, 12
# 54232  PMAI, 12
# 54233  PMAI, 12
# 54234  PMAI, 12
# 54235  PMAI, 12
# 54237  PMAI, 12
# 54239  PMAI, 12
# 54240  PMAI, 12
# 54241  PMAI, 12
# 54242  PMAI, 12
# 54243  PMAI, 12
#
#                                                                                         GO_term  \
# 54202  rRNA processing
# 54219  focal adhesion assembly
# 54220  positive regulation of T-helper 17 cell lineage commitment
# 54222  osteoblast differentiation
# 54223  extracellular matrix organization
# 54224  positive regulation of granulocyte macrophage colony-stimulating factor production
# 54227  positive regulation of NK T cell activation
# 54228  regulation of tyrosine phosphorylation of STAT protein
# 54231  positive regulation of protein kinase B signaling
# 54232  decidualization
# 54233  maturation of LSU-rRNA from tricistronic rRNA transcript (SSU-rRNA, 5.8S rRNA, LSU-rRNA)
# 54234  positive regulation of MAP kinase activity
# 54235  negative regulation of fibroblast growth factor receptor signaling pathway
# 54237  positive regulation of memory T cell differentiation
# 54239  positive regulation of T-helper 17 type immune response
# 54240  negative regulation of osteoblast differentiation
# 54241  ribosomal large subunit biogenesis
# 54242  positive regulation of T cell chemotaxis
# 54243  response to vitamin D
#
#       GO_type  -log10padj
# 54202  BP      4.041132
# 54219  BP      2.371660
# 54220  BP      1.921491
# 54222  BP      1.919213
# 54223  BP      1.914252
# 54224  BP      1.837891
# 54227  BP      1.658726
# 54228  BP      1.658726
# 54231  BP      1.658273
# 54232  BP      1.645445
# 54233  BP      1.628941
# 54234  BP      1.515944
# 54235  BP      1.511323
# 54237  BP      1.472916
# 54239  BP      1.472916
# 54240  BP      1.432284
# 54241  BP      1.400424
# 54242  BP      1.341627
# 54243  BP      1.341627

# %% [markdown]
# # Figures

# %%
fig_prefix = '/data/codec/figs/bulk/'

# %%
filename = fig_prefix + 'heatmap.jaccard.de.gene.sets.cond.time.png'
plt.figure(figsize=(10,10))
ax = plt.gca()
ax.xaxis.tick_top()
ax.yaxis.tick_right()
sns.heatmap(overlap, mask=mask, ax=ax, cbar=None);
plt.title('Jaccard Index of Gene Sets\nDifferentially Expressed from Control')
plt.xticks(rotation=45, ha='left');
plt.tight_layout()
plt.savefig(filename, dpi=80)
plt.close()

# %%
filename = fig_prefix + 'lines.time.specific.de.genes.png'
fig, axs = plt.subplots(1,5,figsize=(25,4.25))
axs[2].text(0.5, 1.15, 'Expression of Time-point-specific Differentially-expressed Genes\nat each Time Point Compared to Control', fontsize=18, transform=axs[2].transAxes, ha='center')
for stim, ax in zip(stims,axs):
    tidy_de_hour = de_hour.reset_index()
    tidy_de_hour = tidy_de_hour[tidy_de_hour['DEGs_FOR'] == stim]
    sns.lineplot(x="TIME",y='Mean Expression',data=tidy_de_hour, hue='SAMPLE', err_style="bars", ci="sd", ax=ax, palette=[color_dict[stim],color_dict['Control']])
    ax.set_title(stim)
    ax.get_legend().remove()
for ax in axs[1:]:
    ax.set_ylabel(None)
plt.savefig(filename, dpi=80)
plt.close()

# %%
filename = fig_prefix + 'barplot.GO.terms.png'
plt.figure(figsize=(10,20))
sns.barplot(data=results_df_no_time[results_df_no_time['GO_term'].isin(highlight)],
            orient="h", x="-log10padj", y='GO_term', hue='Sample', palette=color_dict);
ax = plt.gca()
texts = [i.get_text() for i in ax.get_yticklabels()]

texts[texts.index('interferon-gamma-mediated signaling pathway')] = 'interferon-gamma-mediated\nsignaling pathway'
texts[texts.index('positive regulation of NF-kappaB transcription factor activity')] = 'positive regulation of NF-kappaB\ntranscription factor activity'
texts[texts.index('positive regulation of cell population proliferation')] = 'positive regulation of\ncell population proliferation'

ax.set_yticklabels(texts);
ax.set_ylabel('GO Term');
ax.set_title('Enrichment of GO Terms in\nStimulation Conditions');
plt.tight_layout()
plt.savefig(filename, dpi=80)
plt.close()
